# %% [markdown]
# # Weather Data
# From ALLL Available sources PPG, NOAA Tula, ASCC station, and my stations

# %%
Introduction: 
    - data gaps are a prevalent issue in weather and environmental modeling 
    - currrent methods for filling data gaps include   (need to learn and apply these methods) 
    - issues with these current methods
    - why machiene learning is cool and useful for this (review of current literature) 
    - what We did
    
Methods: 
    - Data collection instruments, and locations, data procuremtns
    - Maybe should try and do the RNN for filling in PPG data gaps, then the other network for comparitive filling

# %% [markdown]
# Notes:
#     for now use daily values. can sub to hourly later maybe if need
#
#     # Old method for ppg data based on static datasets,, us the API instead  (Eventiually)
# (note no other NOAA stations are worth their salt)

# %%
# Clone the entire repo.
# !git clone -l -s git://github.com/cshuler/Machine_Learning_Magic_gap_filling
# %cd Machine_Learning_Magic_gap_filling/Scripts
# !ls
# Out:
# fatal: destination path 'Machine_Learning_Magic_gap_filling' already exists and is not an empty directory.
# /content/Machine_Learning_Magic_gap_filling/Scripts
# baseflow_separator.py	   __pycache__
# getRainfallData.py	   Stream_gap_fill_validation_FIND_Master.ipynb
# key.py			   testmodel_random_callback_save.h5
# Old			   Weather_gap_fill2.ipynb
# PPG_gap_fill_master.ipynb  workspace

# %%
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style> """))

# %matplotlib inline
#%matplotlib notebook

import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy.polynomial.polynomial import polyfit
import seaborn as sns
import os
import io
import datetime
from dateutil import parser, rrule
from datetime import datetime, time, date
import time
import keras 
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
import requests
import scipy
import tensorflow as tf
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import re

# import function from current working directory
from getRainfallData import getRainfallData

workspace = os.path.join('.', 'workspace')
#make sure workspace directory exists
if not os.path.exists(workspace):
    os.makedirs(workspace)


pd.set_option('display.max_rows', 50)    
np.set_printoptions(suppress=True)
# Out:
# <style>
#     div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style>
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# # Firstly, fill in PPG Airport Data completely
# using static data files for now, can switch to an API later when desired to keep all data up to date, will take more work to program
# from http://scacis.rcc-acis.org/ for daily data  and also from: https://www.ncdc.noaa.gov/cdo-web/datasets/LCD/stations/WBAN:61705/detail for hourly data

# %%
path_PPG_data = os.path.join("..", "Data", 'External_weather_data', 'PPG', "daily")                # open dataset
PPG = pd.read_csv(os.path.join(path_PPG_data, 'PPG-2000-oct2-19-daily.csv'), usecols = [2, 5, 13, 18, 19]) #  ,21])  will give wind directions
PPG['DATE'] = pd.to_datetime(PPG['DATE'], errors='coerce')
PPG = PPG.set_index('DATE')

# Now Hourly Airport Data  (junkshow) for needed only for RH data, not in the daily file for some reason, 
path_PPG_data_RH = os.path.join("..", "Data", 'External_weather_data', 'PPG', "hourly")                # open dataset

a = pd.read_csv(os.path.join(path_PPG_data_RH, 'PPG_2010-2019(oct)-hourly.csv'), usecols = [1,2,3, 48])  # cut out rando columns
b = pd.read_csv(os.path.join(path_PPG_data_RH, 'PPG-2000-2009-hourly.csv'), usecols = [1,2,3, 48])       # cut out rando columns
c = pd.concat([b, a])                                                                                    # merge em together

c = c[c['REPORT_TYPE'] == 'FM-15']                                       # apparently the hourly data we want is codes as FM-15 Data
c['DATE'] = pd.to_datetime(c['DATE'], errors='coerce')                   # string date to real date
c['DATE'] = c['DATE'].dt.round('H')                                      # timestamps are in rando near hour times, round to the hour
c = c.set_index('DATE')
del c['REPORT_TYPE']
del c['SOURCE']
c = c.apply(pd.to_numeric, errors='coerce')                       # convert all columns of DataFrame to floats, turns any non-numerics to nan

#  resample to daily values 
PPG_RH_dat = c.resample('D').mean()      # resample the rain different than the other columns
PPG_RH_dat.rename(columns={'HourlyRelativeHumidity': 'RH_pct'}, inplace=True)      # rename column

PPG = PPG.join(PPG_RH_dat)                 #merge the datasets together

PPG.plot(figsize =(12,3))
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Define some functions

# %%
### This is used to Identify and label places where there are gaps in the data

def find_date_gaps(dataset_raw, Colinterest):

    a = dataset_raw[Colinterest].values  # Extract out relevant column from dataframe as array
    ## Now gap filling time: 
    # First: all of this is to go through each dataset and identify the start and the end of each gap. 

    m = np.concatenate(( [True], np.isnan(a), [True] ))  # Mask
    ss = np.flatnonzero(m[1:] != m[:-1]).reshape(-1,2)   # Start-stop limits

    gapstarts_L = []; gapends_L = []
    # this is if the series started late, i.e. the first gap is at the beginning
    if ss[0][0] != 0:     
        gapstart = 0
        gapstarts_L.append(gapstart)
        for m in ss:
            gapstart2 = m[1]
            gapstarts_L.append(gapstart2)
            gapends_L.append(m[0])
        del gapstarts_L[-1]                       # the end number is not the start of a new gap so delete this 

    # this is if the series starst at the beginning of the data period, first gap is in the middle 
    for m in ss:
        gapstarts_L.append(m[1])
        gapends_L.append(m[0])
    del gapstarts_L[-1]
    del gapends_L[0]

    gapstarts_Dates = []; gapends_Dates = []
    for h in gapstarts_L:
        date5 = dataset_raw.index[h]
        gapstarts_Dates.append(date5)   # this is a list of the starting date of all gaps
    for h in gapends_L:
        date5 = dataset_raw.index[h]
        gapends_Dates.append(date5)     # this is a list of all the ending dates of the gaps
           
    # list the 
    for idx, val in enumerate(gapstarts_Dates):
        length = gapends_Dates[idx] -gapstarts_Dates[idx]
        print("gap {} is {} from {} to {}".format(idx, length, gapstarts_Dates[idx], gapends_Dates[idx] ))
    
    return gapstarts_Dates, gapends_Dates

# %%
# this is used to ID gaps and Autofill less than one week long ones

def ID_n_Fill_gaps(dataset_raw):
    
    dataset_cleanish = dataset_raw.copy()    # create output dataset to map fixed data into
    
    for col in dataset_raw.columns: 
        print('...................................................................................')
        print("{} gaps are".format(col))
        
        # ID gaps
        gapstarts_Dates, gapends_Dates =  find_date_gaps(dataset_raw, col)
        
        # Now fill gaps of one day by using average of yesterday's and tomorrow's values
        for idx, val in enumerate(gapstarts_Dates):
            strt = gapstarts_Dates[idx]                                             # note this is the first day with missing data, if only one this is the missing day
            ends = gapends_Dates[idx]                                               # this is the day where there is data again after a gap ( I think) 
            
            if ends - strt < pd.Timedelta('7 day'):                                # if the gap is 1 day long
                beforepoint = dataset_raw[col].loc[strt-pd.Timedelta('7 day')]      # This is the day before the one with the issing data 
                afterpoint = dataset_raw[col].loc[ends]                             # this is the day where there is data again after a gap ( I think) 
                avepoint = np.mean((beforepoint,afterpoint))                        # average of the adjacient values
                dataset_raw[col].loc[strt:ends] = avepoint                       # FILL the GAP with the ave value

        dataset_cleanish[col] = dataset_raw[col]
    
    return dataset_cleanish

# %%
# this is the creation of the DLNN model as a function
def define_model_dense(hidden_layer_sizes, input_shape, activation='relu', optimizer='sgd'):
    
    model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
    model = Sequential()
    
    model.add(Dense(hidden_layer_sizes[0], activation=activation, input_shape=(input_shape, )))
    for hl_size in hidden_layer_sizes[1: ]:
        model.add(Dense(hl_size, activation=activation))
    
    model.add(Dense(1, activation='linear'))
    model.summary()

    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
# implement the ID and fill gaps to take out any small gaps cuz they are annoying.
dataset_raw = PPG.copy()
dataset_cleanish = ID_n_Fill_gaps(dataset_raw)
# Out:
# ...................................................................................
# AWND gaps are
# gap 0 is 427 days 00:00:00 from 2011-10-01 00:00:00 to 2012-12-01 00:00:00
# gap 1 is 1 days 00:00:00 from 2015-02-10 00:00:00 to 2015-02-11 00:00:00
# ...................................................................................
# PRCP gaps are
# gap 0 is 1 days 00:00:00 from 2012-07-31 00:00:00 to 2012-08-01 00:00:00
# gap 1 is 1 days 00:00:00 from 2012-10-31 00:00:00 to 2012-11-01 00:00:00
# gap 2 is 1 days 00:00:00 from 2019-09-01 00:00:00 to 2019-09-02 00:00:00
# ...................................................................................
# TMAX gaps are
# gap 0 is 1 days 00:00:00 from 2019-09-30 00:00:00 to 2019-10-01 00:00:00
# ...................................................................................
# TMIN gaps are
# gap 0 is 1 days 00:00:00 from 2019-09-06 00:00:00 to 2019-09-07 00:00:00
# ...................................................................................
# RH_pct gaps are
# gap 0 is 1 days 00:00:00 from 2011-11-17 00:00:00 to 2011-11-18 00:00:00
# gap 1 is 1 days 00:00:00 from 2011-12-03 00:00:00 to 2011-12-04 00:00:00
# gap 2 is 1 days 00:00:00 from 2011-12-30 00:00:00 to 2011-12-31 00:00:00
# gap 3 is 1 days 00:00:00 from 2012-11-09 00:00:00 to 2012-11-10 00:00:00
# gap 4 is 5 days 00:00:00 from 2012-11-11 00:00:00 to 2012-11-16 00:00:00
# gap 5 is 1 days 00:00:00 from 2012-11-17 00:00:00 to 2012-11-18 00:00:00
# gap 6 is 365 days 00:00:00 from 2015-01-01 00:00:00 to 2016-01-01 00:00:00

# %% [markdown]
# # First order calibration and validation
# ### looking at how well the network matches the training data, this is mainly to assess model performance and uncertainty
# note: need to manually definine columns to work with,

# %%
# this might be automated further in the future but need to find a period where there are no gaps, for now look manually at the potput of this:

ID_n_Fill_gaps(dataset_cleanish)          # just calling this print off a list of the gaps, doesnt do anything since there are no 1 day gaps left. 

""" looks like data is solid from  "2000-01-01"   to "2011-9-30"  """

unbroken_data = dataset_cleanish.loc[:"2011-9-30"]
#unbroken_data.plot()

# double check All is good
print("There are missing values in our train data = {}".format(unbroken_data.isnull().values.any()))
# Out:
# ...................................................................................
# AWND gaps are
# gap 0 is 427 days 00:00:00 from 2011-10-01 00:00:00 to 2012-12-01 00:00:00
# ...................................................................................
# PRCP gaps are
# ...................................................................................
# TMAX gaps are
# ...................................................................................
# TMIN gaps are
# ...................................................................................
# RH_pct gaps are
# gap 0 is 365 days 00:00:00 from 2015-01-01 00:00:00 to 2016-01-01 00:00:00
# There are missing values in our train data = False

# %%
TRAIN_SPLIT = int(len(unbroken_data)*.80)     # train on say 2/3 of the data validate on the rest
# split data for train and validation
train_data = unbroken_data.iloc[:TRAIN_SPLIT]
val_data = unbroken_data.iloc[TRAIN_SPLIT:]


# determine which column to work with
x_cols = ['AWND', 'PRCP', 'TMIN', 'TMAX']
y_col = 'RH_pct'


# set up the training datasets
X_train = train_data[x_cols].values  
# scale the x component of the training data
X_train_scaler = StandardScaler().fit(X_train)
X_train = X_train_scaler.transform(X_train)

y_train = train_data[y_col].values                 # scale the y data too, and then make the scale unique to use it to unscale the final data later
y_train = y_train.reshape(-1, 1)
y_train_scaler = StandardScaler().fit(y_train)
y_train = y_train_scaler.transform(y_train)


# set up the validation datasets
X_val = val_data[x_cols].values  
# scale the x component of the training data
X_val_scaler = StandardScaler().fit(X_val)
X_val = X_val_scaler.transform(X_val)

y_val = val_data[y_col].values
y_val = y_val.reshape(-1, 1)
y_val_scaler = StandardScaler().fit(y_val)
y_val = y_val_scaler.transform(y_val)

# %%
input_shape = len(x_cols)
input_shape
# Out:
# 4

# %%
# this is the creation of the DLNN model as a function
def define_model_dense(hidden_layer_sizes, input_shape, activation='relu', optimizer='sgd'):
    
    model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
    model = Sequential()
    
    model.add(Dense(hidden_layer_sizes[0], activation=activation, input_shape=(input_shape, )))
    for hl_size in hidden_layer_sizes[1: ]:
        model.add(Dense(hl_size, activation=activation))
    
    model.add(Dense(1, activation='linear'))
    model.summary()

    model.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mean_squared_error'])
    
    return model

# %%
#define the DL model and its parameters to use for other models creates object named model in memory

hidden_layer_sizes =  [12, 80, 80]
input_shape = len(x_cols)
activation     = 'relu'
optimizer      = 'sgd'

model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
model = define_model_dense(hidden_layer_sizes, input_shape, activation, optimizer)

# train the network
# Note using callbacks from ( https://www.machinecurve.com/index.php/2019/05/30/avoid-wasting-resources-with-earlystopping-and-modelcheckpoint-in-keras/ )
checkpoint_path = os.path.join(workspace, 'testmodel_random_callback_save2.h5')

keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=150, mode='min', min_delta=0.001),
                     ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')]

history = model.fit(X_train, y_train, epochs=2000,verbose=1, validation_data =(X_val,  y_val), callbacks=keras_callbacks)

## load the best saved model based on validation loss
model = load_model(checkpoint_path)
scores = model.evaluate(X_train, y_train, verbose=1)
print(f'Score: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_161 (Dense)            (None, 12)                60
# _________________________________________________________________
# dense_162 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_163 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_164 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,661
# Trainable params: 7,661
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3432 samples, validate on 859 samples
# Epoch 1/2000
# 3432/3432 [==============================] - 4s 1ms/step - loss: 0.7395 - mean_squared_error: 0.8877 - val_loss: 0.7277 - val_mean_squared_error: 0.8253
# Epoch 2/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.6736 - mean_squared_error: 0.7701 - val_loss: 0.7171 - val_mean_squared_error: 0.8138
# Epoch 3/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.6589 - mean_squared_error: 0.7530 - val_loss: 0.7145 - val_mean_squared_error: 0.8035
# Epoch 4/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.6502 - mean_squared_error: 0.7349 - val_loss: 0.7045 - val_mean_squared_error: 0.8095
# Epoch 5/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.6435 - mean_squared_error: 0.7278 - val_loss: 0.7045 - val_mean_squared_error: 0.7970
# Epoch 6/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.6387 - mean_squared_error: 0.7192 - val_loss: 0.7077 - val_mean_squared_error: 0.7996
# Epoch 7/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6344 - mean_squared_error: 0.7111 - val_loss: 0.7140 - val_mean_squared_error: 0.8038
# Epoch 8/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6314 - mean_squared_error: 0.7078 - val_loss: 0.7055 - val_mean_squared_error: 0.7980
# Epoch 9/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6282 - mean_squared_error: 0.7031 - val_loss: 0.7078 - val_mean_squared_error: 0.8203
# Epoch 10/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.6263 - mean_squared_error: 0.7018 - val_loss: 0.7017 - val_mean_squared_error: 0.7970
# Epoch 11/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6238 - mean_squared_error: 0.6944 - val_loss: 0.7066 - val_mean_squared_error: 0.8033
# Epoch 12/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6227 - mean_squared_error: 0.6933 - val_loss: 0.7039 - val_mean_squared_error: 0.8058
# Epoch 13/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.6209 - mean_squared_error: 0.6879 - val_loss: 0.7021 - val_mean_squared_error: 0.7975
# Epoch 14/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6192 - mean_squared_error: 0.6842 - val_loss: 0.7078 - val_mean_squared_error: 0.7938
# Epoch 15/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6177 - mean_squared_error: 0.6816 - val_loss: 0.6996 - val_mean_squared_error: 0.7985
# Epoch 16/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6167 - mean_squared_error: 0.6793 - val_loss: 0.6999 - val_mean_squared_error: 0.7930
# Epoch 17/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6165 - mean_squared_error: 0.6779 - val_loss: 0.7038 - val_mean_squared_error: 0.7883
# Epoch 18/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.6144 - mean_squared_error: 0.6746 - val_loss: 0.7083 - val_mean_squared_error: 0.7935
# Epoch 19/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.6139 - mean_squared_error: 0.6723 - val_loss: 0.7069 - val_mean_squared_error: 0.7930
# Epoch 20/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6136 - mean_squared_error: 0.6750 - val_loss: 0.7006 - val_mean_squared_error: 0.7844
# Epoch 21/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.6123 - mean_squared_error: 0.6694 - val_loss: 0.7033 - val_mean_squared_error: 0.7982
# Epoch 22/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6119 - mean_squared_error: 0.6693 - val_loss: 0.7007 - val_mean_squared_error: 0.7905
# Epoch 23/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6111 - mean_squared_error: 0.6655 - val_loss: 0.6969 - val_mean_squared_error: 0.7838
# Epoch 24/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6111 - mean_squared_error: 0.6641 - val_loss: 0.6975 - val_mean_squared_error: 0.7784
# Epoch 25/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6099 - mean_squared_error: 0.6643 - val_loss: 0.6952 - val_mean_squared_error: 0.7820
# Epoch 26/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.6094 - mean_squared_error: 0.6636 - val_loss: 0.6939 - val_mean_squared_error: 0.7782
# Epoch 27/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.6089 - mean_squared_error: 0.6615 - val_loss: 0.6975 - val_mean_squared_error: 0.7785
# Epoch 28/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6089 - mean_squared_error: 0.6623 - val_loss: 0.6987 - val_mean_squared_error: 0.7748
# Epoch 29/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6089 - mean_squared_error: 0.6601 - val_loss: 0.6981 - val_mean_squared_error: 0.7764
# Epoch 30/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.6074 - mean_squared_error: 0.6590 - val_loss: 0.6922 - val_mean_squared_error: 0.7744
# Epoch 31/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.6076 - mean_squared_error: 0.6571 - val_loss: 0.6964 - val_mean_squared_error: 0.7762
# Epoch 32/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6071 - mean_squared_error: 0.6546 - val_loss: 0.7003 - val_mean_squared_error: 0.7773
# Epoch 33/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.6068 - mean_squared_error: 0.6559 - val_loss: 0.6966 - val_mean_squared_error: 0.7726
# Epoch 34/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.6073 - mean_squared_error: 0.6554 - val_loss: 0.6909 - val_mean_squared_error: 0.7807
# Epoch 35/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.6062 - mean_squared_error: 0.6563 - val_loss: 0.6946 - val_mean_squared_error: 0.7926
# Epoch 36/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6066 - mean_squared_error: 0.6543 - val_loss: 0.6953 - val_mean_squared_error: 0.7760
# Epoch 37/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6061 - mean_squared_error: 0.6523 - val_loss: 0.6946 - val_mean_squared_error: 0.7975
# Epoch 38/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6055 - mean_squared_error: 0.6545 - val_loss: 0.6904 - val_mean_squared_error: 0.7794
# Epoch 39/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.6050 - mean_squared_error: 0.6524 - val_loss: 0.7008 - val_mean_squared_error: 0.7761
# Epoch 40/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.6056 - mean_squared_error: 0.6525 - val_loss: 0.6942 - val_mean_squared_error: 0.7721
# Epoch 41/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.6040 - mean_squared_error: 0.6493 - val_loss: 0.6908 - val_mean_squared_error: 0.7699
# Epoch 42/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6033 - mean_squared_error: 0.6512 - val_loss: 0.6971 - val_mean_squared_error: 0.7696
# Epoch 43/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6037 - mean_squared_error: 0.6473 - val_loss: 0.7052 - val_mean_squared_error: 0.7741
# Epoch 44/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.6038 - mean_squared_error: 0.6461 - val_loss: 0.6968 - val_mean_squared_error: 0.7714
# Epoch 45/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6030 - mean_squared_error: 0.6504 - val_loss: 0.6960 - val_mean_squared_error: 0.7883
# Epoch 46/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6040 - mean_squared_error: 0.6464 - val_loss: 0.7081 - val_mean_squared_error: 0.7784
# Epoch 47/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.6028 - mean_squared_error: 0.6469 - val_loss: 0.6953 - val_mean_squared_error: 0.7833
# Epoch 48/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.6016 - mean_squared_error: 0.6468 - val_loss: 0.6943 - val_mean_squared_error: 0.7702
# Epoch 49/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6015 - mean_squared_error: 0.6458 - val_loss: 0.7032 - val_mean_squared_error: 0.7719
# Epoch 50/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6016 - mean_squared_error: 0.6433 - val_loss: 0.6934 - val_mean_squared_error: 0.7995
# Epoch 51/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6023 - mean_squared_error: 0.6465 - val_loss: 0.6879 - val_mean_squared_error: 0.7863
# Epoch 52/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6015 - mean_squared_error: 0.6416 - val_loss: 0.6875 - val_mean_squared_error: 0.7727
# Epoch 53/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6006 - mean_squared_error: 0.6411 - val_loss: 0.6908 - val_mean_squared_error: 0.7710
# Epoch 54/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.6011 - mean_squared_error: 0.6428 - val_loss: 0.6903 - val_mean_squared_error: 0.7823
# Epoch 55/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6002 - mean_squared_error: 0.6411 - val_loss: 0.6841 - val_mean_squared_error: 0.7754
# Epoch 56/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.6001 - mean_squared_error: 0.6395 - val_loss: 0.6911 - val_mean_squared_error: 0.7672
# Epoch 57/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.6010 - mean_squared_error: 0.6385 - val_loss: 0.6977 - val_mean_squared_error: 0.7692
# Epoch 58/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5994 - mean_squared_error: 0.6414 - val_loss: 0.6971 - val_mean_squared_error: 0.7676
# Epoch 59/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5997 - mean_squared_error: 0.6384 - val_loss: 0.6913 - val_mean_squared_error: 0.7734
# Epoch 60/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5983 - mean_squared_error: 0.6379 - val_loss: 0.6915 - val_mean_squared_error: 0.7815
# Epoch 61/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5993 - mean_squared_error: 0.6387 - val_loss: 0.6885 - val_mean_squared_error: 0.7780
# Epoch 62/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5992 - mean_squared_error: 0.6379 - val_loss: 0.6902 - val_mean_squared_error: 0.7741
# Epoch 63/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5993 - mean_squared_error: 0.6367 - val_loss: 0.7096 - val_mean_squared_error: 0.7751
# Epoch 64/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5980 - mean_squared_error: 0.6345 - val_loss: 0.7025 - val_mean_squared_error: 0.7696
# Epoch 65/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5970 - mean_squared_error: 0.6352 - val_loss: 0.7017 - val_mean_squared_error: 0.7817
# Epoch 66/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5987 - mean_squared_error: 0.6358 - val_loss: 0.6985 - val_mean_squared_error: 0.7738
# Epoch 67/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5975 - mean_squared_error: 0.6366 - val_loss: 0.6878 - val_mean_squared_error: 0.7690
# Epoch 68/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5973 - mean_squared_error: 0.6309 - val_loss: 0.6977 - val_mean_squared_error: 0.7714
# Epoch 69/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5974 - mean_squared_error: 0.6352 - val_loss: 0.6892 - val_mean_squared_error: 0.7775
# Epoch 70/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5966 - mean_squared_error: 0.6318 - val_loss: 0.6907 - val_mean_squared_error: 0.7900
# Epoch 71/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5977 - mean_squared_error: 0.6336 - val_loss: 0.6899 - val_mean_squared_error: 0.7701
# Epoch 72/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5974 - mean_squared_error: 0.6321 - val_loss: 0.7013 - val_mean_squared_error: 0.7674
# Epoch 73/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5966 - mean_squared_error: 0.6297 - val_loss: 0.6882 - val_mean_squared_error: 0.7615
# Epoch 74/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5968 - mean_squared_error: 0.6324 - val_loss: 0.6897 - val_mean_squared_error: 0.7834
# Epoch 75/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5954 - mean_squared_error: 0.6307 - val_loss: 0.7334 - val_mean_squared_error: 0.8114
# Epoch 76/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5973 - mean_squared_error: 0.6340 - val_loss: 0.6853 - val_mean_squared_error: 0.7667
# Epoch 77/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5961 - mean_squared_error: 0.6296 - val_loss: 0.6912 - val_mean_squared_error: 0.7780
# Epoch 78/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5949 - mean_squared_error: 0.6319 - val_loss: 0.6961 - val_mean_squared_error: 0.8100
# Epoch 79/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5946 - mean_squared_error: 0.6316 - val_loss: 0.6914 - val_mean_squared_error: 0.7688
# Epoch 80/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5956 - mean_squared_error: 0.6268 - val_loss: 0.6869 - val_mean_squared_error: 0.7810
# Epoch 81/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5948 - mean_squared_error: 0.6258 - val_loss: 0.6952 - val_mean_squared_error: 0.7597
# Epoch 82/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5946 - mean_squared_error: 0.6291 - val_loss: 0.6948 - val_mean_squared_error: 0.7776
# Epoch 83/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5942 - mean_squared_error: 0.6274 - val_loss: 0.6973 - val_mean_squared_error: 0.7720
# Epoch 84/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5948 - mean_squared_error: 0.6293 - val_loss: 0.6944 - val_mean_squared_error: 0.7611
# Epoch 85/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5936 - mean_squared_error: 0.6285 - val_loss: 0.7080 - val_mean_squared_error: 0.7708
# Epoch 86/2000
# 3432/3432 [==============================] - 0s 66us/step - loss: 0.5937 - mean_squared_error: 0.6278 - val_loss: 0.6865 - val_mean_squared_error: 0.7558
# Epoch 87/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.5931 - mean_squared_error: 0.6231 - val_loss: 0.6893 - val_mean_squared_error: 0.7862
# Epoch 88/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5937 - mean_squared_error: 0.6264 - val_loss: 0.6967 - val_mean_squared_error: 0.7808
# Epoch 89/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5942 - mean_squared_error: 0.6272 - val_loss: 0.6920 - val_mean_squared_error: 0.7638
# Epoch 90/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5937 - mean_squared_error: 0.6255 - val_loss: 0.6941 - val_mean_squared_error: 0.7677
# Epoch 91/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5938 - mean_squared_error: 0.6310 - val_loss: 0.6946 - val_mean_squared_error: 0.7926
# Epoch 92/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5926 - mean_squared_error: 0.6249 - val_loss: 0.6940 - val_mean_squared_error: 0.7711
# Epoch 93/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5934 - mean_squared_error: 0.6256 - val_loss: 0.7002 - val_mean_squared_error: 0.7658
# Epoch 94/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5926 - mean_squared_error: 0.6249 - val_loss: 0.7002 - val_mean_squared_error: 0.7673
# Epoch 95/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5935 - mean_squared_error: 0.6224 - val_loss: 0.6939 - val_mean_squared_error: 0.7874
# Epoch 96/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5920 - mean_squared_error: 0.6231 - val_loss: 0.6882 - val_mean_squared_error: 0.7973
# Epoch 97/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5928 - mean_squared_error: 0.6282 - val_loss: 0.6947 - val_mean_squared_error: 0.7599
# Epoch 98/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5923 - mean_squared_error: 0.6238 - val_loss: 0.6941 - val_mean_squared_error: 0.7608
# Epoch 99/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5924 - mean_squared_error: 0.6212 - val_loss: 0.6886 - val_mean_squared_error: 0.7729
# Epoch 100/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5918 - mean_squared_error: 0.6224 - val_loss: 0.6885 - val_mean_squared_error: 0.7722
# Epoch 101/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5915 - mean_squared_error: 0.6253 - val_loss: 0.6818 - val_mean_squared_error: 0.7770
# Epoch 102/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5923 - mean_squared_error: 0.6240 - val_loss: 0.6891 - val_mean_squared_error: 0.7622
# Epoch 103/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5908 - mean_squared_error: 0.6191 - val_loss: 0.6917 - val_mean_squared_error: 0.7847
# Epoch 104/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5905 - mean_squared_error: 0.6248 - val_loss: 0.6901 - val_mean_squared_error: 0.7547
# Epoch 105/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5917 - mean_squared_error: 0.6202 - val_loss: 0.6982 - val_mean_squared_error: 0.7607
# Epoch 106/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5912 - mean_squared_error: 0.6176 - val_loss: 0.6950 - val_mean_squared_error: 0.7846
# Epoch 107/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5911 - mean_squared_error: 0.6236 - val_loss: 0.6864 - val_mean_squared_error: 0.7878
# Epoch 108/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5907 - mean_squared_error: 0.6191 - val_loss: 0.6896 - val_mean_squared_error: 0.7629
# Epoch 109/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5894 - mean_squared_error: 0.6209 - val_loss: 0.6892 - val_mean_squared_error: 0.7529
# Epoch 110/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5901 - mean_squared_error: 0.6170 - val_loss: 0.6933 - val_mean_squared_error: 0.7791
# Epoch 111/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5899 - mean_squared_error: 0.6184 - val_loss: 0.6973 - val_mean_squared_error: 0.7687
# Epoch 112/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5906 - mean_squared_error: 0.6194 - val_loss: 0.7163 - val_mean_squared_error: 0.7875
# Epoch 113/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5911 - mean_squared_error: 0.6209 - val_loss: 0.6910 - val_mean_squared_error: 0.7822
# Epoch 114/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5900 - mean_squared_error: 0.6169 - val_loss: 0.7041 - val_mean_squared_error: 0.7704
# Epoch 115/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5898 - mean_squared_error: 0.6163 - val_loss: 0.6951 - val_mean_squared_error: 0.7652
# Epoch 116/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5908 - mean_squared_error: 0.6173 - val_loss: 0.6982 - val_mean_squared_error: 0.8062
# Epoch 117/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5896 - mean_squared_error: 0.6151 - val_loss: 0.6904 - val_mean_squared_error: 0.7931
# Epoch 118/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5899 - mean_squared_error: 0.6172 - val_loss: 0.6918 - val_mean_squared_error: 0.7609
# Epoch 119/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5884 - mean_squared_error: 0.6156 - val_loss: 0.6915 - val_mean_squared_error: 0.7834
# Epoch 120/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5888 - mean_squared_error: 0.6151 - val_loss: 0.6968 - val_mean_squared_error: 0.7672
# Epoch 121/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5901 - mean_squared_error: 0.6174 - val_loss: 0.6905 - val_mean_squared_error: 0.7688
# Epoch 122/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5895 - mean_squared_error: 0.6148 - val_loss: 0.6806 - val_mean_squared_error: 0.7630
# Epoch 123/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5885 - mean_squared_error: 0.6146 - val_loss: 0.6879 - val_mean_squared_error: 0.7601
# Epoch 124/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5892 - mean_squared_error: 0.6149 - val_loss: 0.6981 - val_mean_squared_error: 0.7615
# Epoch 125/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5871 - mean_squared_error: 0.6099 - val_loss: 0.6971 - val_mean_squared_error: 0.8082
# Epoch 126/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5879 - mean_squared_error: 0.6153 - val_loss: 0.6889 - val_mean_squared_error: 0.7851
# Epoch 127/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5880 - mean_squared_error: 0.6149 - val_loss: 0.6887 - val_mean_squared_error: 0.7616
# Epoch 128/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5879 - mean_squared_error: 0.6138 - val_loss: 0.7012 - val_mean_squared_error: 0.7767
# Epoch 129/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5883 - mean_squared_error: 0.6142 - val_loss: 0.6848 - val_mean_squared_error: 0.7826
# Epoch 130/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5881 - mean_squared_error: 0.6150 - val_loss: 0.6821 - val_mean_squared_error: 0.7522
# Epoch 131/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5877 - mean_squared_error: 0.6111 - val_loss: 0.6863 - val_mean_squared_error: 0.7787
# Epoch 132/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5868 - mean_squared_error: 0.6123 - val_loss: 0.6969 - val_mean_squared_error: 0.7821
# Epoch 133/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5863 - mean_squared_error: 0.6093 - val_loss: 0.7034 - val_mean_squared_error: 0.7754
# Epoch 134/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5868 - mean_squared_error: 0.6107 - val_loss: 0.6999 - val_mean_squared_error: 0.7749
# Epoch 135/2000
# 3432/3432 [==============================] - 0s 66us/step - loss: 0.5871 - mean_squared_error: 0.6118 - val_loss: 0.7013 - val_mean_squared_error: 0.7844
# Epoch 136/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5874 - mean_squared_error: 0.6106 - val_loss: 0.6875 - val_mean_squared_error: 0.7546
# Epoch 137/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5873 - mean_squared_error: 0.6123 - val_loss: 0.6938 - val_mean_squared_error: 0.7698
# Epoch 138/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5874 - mean_squared_error: 0.6140 - val_loss: 0.6855 - val_mean_squared_error: 0.7711
# Epoch 139/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5862 - mean_squared_error: 0.6102 - val_loss: 0.6898 - val_mean_squared_error: 0.7914
# Epoch 140/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5856 - mean_squared_error: 0.6110 - val_loss: 0.6835 - val_mean_squared_error: 0.7529
# Epoch 141/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5861 - mean_squared_error: 0.6103 - val_loss: 0.6822 - val_mean_squared_error: 0.7508
# Epoch 142/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5861 - mean_squared_error: 0.6141 - val_loss: 0.6791 - val_mean_squared_error: 0.7578
# Epoch 143/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5858 - mean_squared_error: 0.6095 - val_loss: 0.7003 - val_mean_squared_error: 0.7704
# Epoch 144/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5857 - mean_squared_error: 0.6092 - val_loss: 0.6990 - val_mean_squared_error: 0.8165
# Epoch 145/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5867 - mean_squared_error: 0.6107 - val_loss: 0.6882 - val_mean_squared_error: 0.7618
# Epoch 146/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5857 - mean_squared_error: 0.6114 - val_loss: 0.6838 - val_mean_squared_error: 0.7676
# Epoch 147/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5857 - mean_squared_error: 0.6096 - val_loss: 0.6977 - val_mean_squared_error: 0.7597
# Epoch 148/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5859 - mean_squared_error: 0.6081 - val_loss: 0.6817 - val_mean_squared_error: 0.7646
# Epoch 149/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5840 - mean_squared_error: 0.6065 - val_loss: 0.7020 - val_mean_squared_error: 0.7576
# Epoch 150/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5855 - mean_squared_error: 0.6072 - val_loss: 0.6829 - val_mean_squared_error: 0.7551
# Epoch 151/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5834 - mean_squared_error: 0.6060 - val_loss: 0.7014 - val_mean_squared_error: 0.8116
# Epoch 152/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5853 - mean_squared_error: 0.6092 - val_loss: 0.6938 - val_mean_squared_error: 0.8005
# Epoch 153/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5865 - mean_squared_error: 0.6091 - val_loss: 0.6968 - val_mean_squared_error: 0.7713
# Epoch 154/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5842 - mean_squared_error: 0.6032 - val_loss: 0.6972 - val_mean_squared_error: 0.8014
# Epoch 155/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5849 - mean_squared_error: 0.6064 - val_loss: 0.7048 - val_mean_squared_error: 0.8347
# Epoch 156/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5847 - mean_squared_error: 0.6090 - val_loss: 0.6871 - val_mean_squared_error: 0.7536
# Epoch 157/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5841 - mean_squared_error: 0.6085 - val_loss: 0.6875 - val_mean_squared_error: 0.7746
# Epoch 158/2000
# 3432/3432 [==============================] - 0s 78us/step - loss: 0.5845 - mean_squared_error: 0.6083 - val_loss: 0.6947 - val_mean_squared_error: 0.7570
# Epoch 159/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5832 - mean_squared_error: 0.6045 - val_loss: 0.6861 - val_mean_squared_error: 0.7692
# Epoch 160/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5857 - mean_squared_error: 0.6071 - val_loss: 0.6802 - val_mean_squared_error: 0.7504
# Epoch 161/2000
# 3432/3432 [==============================] - 0s 66us/step - loss: 0.5843 - mean_squared_error: 0.6051 - val_loss: 0.6862 - val_mean_squared_error: 0.7624
# Epoch 162/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5837 - mean_squared_error: 0.6056 - val_loss: 0.6858 - val_mean_squared_error: 0.7716
# Epoch 163/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5835 - mean_squared_error: 0.6055 - val_loss: 0.6878 - val_mean_squared_error: 0.7992
# Epoch 164/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5850 - mean_squared_error: 0.6047 - val_loss: 0.6899 - val_mean_squared_error: 0.7766
# Epoch 165/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5839 - mean_squared_error: 0.6043 - val_loss: 0.6978 - val_mean_squared_error: 0.7667
# Epoch 166/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5816 - mean_squared_error: 0.6028 - val_loss: 0.6863 - val_mean_squared_error: 0.7566
# Epoch 167/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5836 - mean_squared_error: 0.6051 - val_loss: 0.6907 - val_mean_squared_error: 0.7564
# Epoch 168/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5841 - mean_squared_error: 0.6021 - val_loss: 0.6929 - val_mean_squared_error: 0.7612
# Epoch 169/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5833 - mean_squared_error: 0.6048 - val_loss: 0.6883 - val_mean_squared_error: 0.7674
# Epoch 170/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5829 - mean_squared_error: 0.6043 - val_loss: 0.6873 - val_mean_squared_error: 0.7818
# Epoch 171/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5837 - mean_squared_error: 0.6033 - val_loss: 0.6790 - val_mean_squared_error: 0.7410
# Epoch 172/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5834 - mean_squared_error: 0.6061 - val_loss: 0.6851 - val_mean_squared_error: 0.7580
# Epoch 173/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5821 - mean_squared_error: 0.6022 - val_loss: 0.6964 - val_mean_squared_error: 0.7649
# Epoch 174/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5811 - mean_squared_error: 0.6005 - val_loss: 0.6952 - val_mean_squared_error: 0.7874
# Epoch 175/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5830 - mean_squared_error: 0.6009 - val_loss: 0.6864 - val_mean_squared_error: 0.7437
# Epoch 176/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5817 - mean_squared_error: 0.6032 - val_loss: 0.6900 - val_mean_squared_error: 0.7693
# Epoch 177/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5824 - mean_squared_error: 0.6051 - val_loss: 0.6918 - val_mean_squared_error: 0.7663
# Epoch 178/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5809 - mean_squared_error: 0.6030 - val_loss: 0.6953 - val_mean_squared_error: 0.8116
# Epoch 179/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5817 - mean_squared_error: 0.6026 - val_loss: 0.6780 - val_mean_squared_error: 0.7678
# Epoch 180/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5822 - mean_squared_error: 0.6061 - val_loss: 0.6902 - val_mean_squared_error: 0.7787
# Epoch 181/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5821 - mean_squared_error: 0.6023 - val_loss: 0.6871 - val_mean_squared_error: 0.7488
# Epoch 182/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5814 - mean_squared_error: 0.6023 - val_loss: 0.6908 - val_mean_squared_error: 0.7804
# Epoch 183/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5807 - mean_squared_error: 0.5970 - val_loss: 0.6862 - val_mean_squared_error: 0.7902
# Epoch 184/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5811 - mean_squared_error: 0.6008 - val_loss: 0.6978 - val_mean_squared_error: 0.8187
# Epoch 185/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5826 - mean_squared_error: 0.6059 - val_loss: 0.6909 - val_mean_squared_error: 0.7742
# Epoch 186/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5809 - mean_squared_error: 0.6002 - val_loss: 0.6888 - val_mean_squared_error: 0.7603
# Epoch 187/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5796 - mean_squared_error: 0.5986 - val_loss: 0.6902 - val_mean_squared_error: 0.7648
# Epoch 188/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5806 - mean_squared_error: 0.5982 - val_loss: 0.6869 - val_mean_squared_error: 0.7684
# Epoch 189/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5803 - mean_squared_error: 0.5978 - val_loss: 0.6874 - val_mean_squared_error: 0.7782
# Epoch 190/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5807 - mean_squared_error: 0.6003 - val_loss: 0.6953 - val_mean_squared_error: 0.7647
# Epoch 191/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5808 - mean_squared_error: 0.5993 - val_loss: 0.6841 - val_mean_squared_error: 0.7612
# Epoch 192/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5798 - mean_squared_error: 0.5983 - val_loss: 0.6813 - val_mean_squared_error: 0.7869
# Epoch 193/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5793 - mean_squared_error: 0.5996 - val_loss: 0.7019 - val_mean_squared_error: 0.7647
# Epoch 194/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5805 - mean_squared_error: 0.5950 - val_loss: 0.7005 - val_mean_squared_error: 0.7995
# Epoch 195/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5807 - mean_squared_error: 0.5990 - val_loss: 0.6926 - val_mean_squared_error: 0.7800
# Epoch 196/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5802 - mean_squared_error: 0.5982 - val_loss: 0.6975 - val_mean_squared_error: 0.8223
# Epoch 197/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5791 - mean_squared_error: 0.5947 - val_loss: 0.6991 - val_mean_squared_error: 0.8130
# Epoch 198/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5810 - mean_squared_error: 0.6000 - val_loss: 0.6803 - val_mean_squared_error: 0.7691
# Epoch 199/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5793 - mean_squared_error: 0.5949 - val_loss: 0.6853 - val_mean_squared_error: 0.7760
# Epoch 200/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5785 - mean_squared_error: 0.5947 - val_loss: 0.7006 - val_mean_squared_error: 0.7806
# Epoch 201/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5794 - mean_squared_error: 0.5996 - val_loss: 0.6878 - val_mean_squared_error: 0.7584
# Epoch 202/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5790 - mean_squared_error: 0.5982 - val_loss: 0.7015 - val_mean_squared_error: 0.8194
# Epoch 203/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5777 - mean_squared_error: 0.5972 - val_loss: 0.6956 - val_mean_squared_error: 0.7697
# Epoch 204/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5801 - mean_squared_error: 0.6009 - val_loss: 0.6905 - val_mean_squared_error: 0.7755
# Epoch 205/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5791 - mean_squared_error: 0.5946 - val_loss: 0.6956 - val_mean_squared_error: 0.7713
# Epoch 206/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5786 - mean_squared_error: 0.5966 - val_loss: 0.6794 - val_mean_squared_error: 0.7492
# Epoch 207/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5783 - mean_squared_error: 0.5974 - val_loss: 0.7051 - val_mean_squared_error: 0.7806
# Epoch 208/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5787 - mean_squared_error: 0.5948 - val_loss: 0.7004 - val_mean_squared_error: 0.8125
# Epoch 209/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5776 - mean_squared_error: 0.5964 - val_loss: 0.6849 - val_mean_squared_error: 0.7712
# Epoch 210/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5770 - mean_squared_error: 0.5916 - val_loss: 0.6886 - val_mean_squared_error: 0.7858
# Epoch 211/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5770 - mean_squared_error: 0.5934 - val_loss: 0.7052 - val_mean_squared_error: 0.8429
# Epoch 212/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5761 - mean_squared_error: 0.5915 - val_loss: 0.6968 - val_mean_squared_error: 0.7689
# Epoch 213/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5780 - mean_squared_error: 0.5954 - val_loss: 0.7016 - val_mean_squared_error: 0.8144
# Epoch 214/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5785 - mean_squared_error: 0.5950 - val_loss: 0.6757 - val_mean_squared_error: 0.7673
# Epoch 215/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5772 - mean_squared_error: 0.5918 - val_loss: 0.7020 - val_mean_squared_error: 0.7941
# Epoch 216/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5771 - mean_squared_error: 0.5952 - val_loss: 0.6991 - val_mean_squared_error: 0.7940
# Epoch 217/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5757 - mean_squared_error: 0.5923 - val_loss: 0.7012 - val_mean_squared_error: 0.8112
# Epoch 218/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5763 - mean_squared_error: 0.5891 - val_loss: 0.7036 - val_mean_squared_error: 0.7956
# Epoch 219/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5770 - mean_squared_error: 0.5904 - val_loss: 0.6892 - val_mean_squared_error: 0.7533
# Epoch 220/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5778 - mean_squared_error: 0.5963 - val_loss: 0.6962 - val_mean_squared_error: 0.7792
# Epoch 221/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5768 - mean_squared_error: 0.5939 - val_loss: 0.6951 - val_mean_squared_error: 0.7796
# Epoch 222/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5748 - mean_squared_error: 0.5910 - val_loss: 0.6990 - val_mean_squared_error: 0.7896
# Epoch 223/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5766 - mean_squared_error: 0.5919 - val_loss: 0.7076 - val_mean_squared_error: 0.8429
# Epoch 224/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5769 - mean_squared_error: 0.5966 - val_loss: 0.7114 - val_mean_squared_error: 0.8501
# Epoch 225/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5775 - mean_squared_error: 0.5969 - val_loss: 0.6912 - val_mean_squared_error: 0.8003
# Epoch 226/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5765 - mean_squared_error: 0.5921 - val_loss: 0.7021 - val_mean_squared_error: 0.7736
# Epoch 227/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.5755 - mean_squared_error: 0.5889 - val_loss: 0.6967 - val_mean_squared_error: 0.7810
# Epoch 228/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5760 - mean_squared_error: 0.5915 - val_loss: 0.7097 - val_mean_squared_error: 0.8030
# Epoch 229/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5749 - mean_squared_error: 0.5918 - val_loss: 0.7126 - val_mean_squared_error: 0.8699
# Epoch 230/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5761 - mean_squared_error: 0.5900 - val_loss: 0.6885 - val_mean_squared_error: 0.7654
# Epoch 231/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5753 - mean_squared_error: 0.5910 - val_loss: 0.7074 - val_mean_squared_error: 0.7699
# Epoch 232/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5756 - mean_squared_error: 0.5909 - val_loss: 0.6816 - val_mean_squared_error: 0.7787
# Epoch 233/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5747 - mean_squared_error: 0.5910 - val_loss: 0.6981 - val_mean_squared_error: 0.8111
# Epoch 234/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5740 - mean_squared_error: 0.5894 - val_loss: 0.6866 - val_mean_squared_error: 0.7824
# Epoch 235/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5736 - mean_squared_error: 0.5909 - val_loss: 0.6954 - val_mean_squared_error: 0.7909
# Epoch 236/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5747 - mean_squared_error: 0.5930 - val_loss: 0.6940 - val_mean_squared_error: 0.7635
# Epoch 237/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5742 - mean_squared_error: 0.5872 - val_loss: 0.6960 - val_mean_squared_error: 0.7901
# Epoch 238/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5744 - mean_squared_error: 0.5896 - val_loss: 0.6950 - val_mean_squared_error: 0.8166
# Epoch 239/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5732 - mean_squared_error: 0.5889 - val_loss: 0.6934 - val_mean_squared_error: 0.8247
# Epoch 240/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5735 - mean_squared_error: 0.5856 - val_loss: 0.6868 - val_mean_squared_error: 0.7798
# Epoch 241/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5732 - mean_squared_error: 0.5870 - val_loss: 0.6903 - val_mean_squared_error: 0.8017
# Epoch 242/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5740 - mean_squared_error: 0.5897 - val_loss: 0.6988 - val_mean_squared_error: 0.7896
# Epoch 243/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5748 - mean_squared_error: 0.5869 - val_loss: 0.6982 - val_mean_squared_error: 0.7946
# Epoch 244/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5728 - mean_squared_error: 0.5883 - val_loss: 0.6925 - val_mean_squared_error: 0.7591
# Epoch 245/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5745 - mean_squared_error: 0.5922 - val_loss: 0.7487 - val_mean_squared_error: 0.8479
# Epoch 246/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5734 - mean_squared_error: 0.5879 - val_loss: 0.6956 - val_mean_squared_error: 0.7788
# Epoch 247/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5739 - mean_squared_error: 0.5878 - val_loss: 0.6902 - val_mean_squared_error: 0.7601
# Epoch 248/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5734 - mean_squared_error: 0.5871 - val_loss: 0.6782 - val_mean_squared_error: 0.7664
# Epoch 249/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5731 - mean_squared_error: 0.5875 - val_loss: 0.6902 - val_mean_squared_error: 0.7756
# Epoch 250/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5729 - mean_squared_error: 0.5868 - val_loss: 0.7125 - val_mean_squared_error: 0.8133
# Epoch 251/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5728 - mean_squared_error: 0.5895 - val_loss: 0.6906 - val_mean_squared_error: 0.7819
# Epoch 252/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5738 - mean_squared_error: 0.5878 - val_loss: 0.7070 - val_mean_squared_error: 0.8221
# Epoch 253/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5734 - mean_squared_error: 0.5912 - val_loss: 0.7030 - val_mean_squared_error: 0.8195
# Epoch 254/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5712 - mean_squared_error: 0.5895 - val_loss: 0.7002 - val_mean_squared_error: 0.8020
# Epoch 255/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5725 - mean_squared_error: 0.5853 - val_loss: 0.7026 - val_mean_squared_error: 0.8474
# Epoch 256/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5730 - mean_squared_error: 0.5898 - val_loss: 0.7173 - val_mean_squared_error: 0.8685
# Epoch 257/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5721 - mean_squared_error: 0.5905 - val_loss: 0.6871 - val_mean_squared_error: 0.7651
# Epoch 258/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5722 - mean_squared_error: 0.5805 - val_loss: 0.6976 - val_mean_squared_error: 0.8055
# Epoch 259/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5722 - mean_squared_error: 0.5890 - val_loss: 0.7141 - val_mean_squared_error: 0.8056
# Epoch 260/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5696 - mean_squared_error: 0.5840 - val_loss: 0.7235 - val_mean_squared_error: 0.9055
# Epoch 261/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5735 - mean_squared_error: 0.5860 - val_loss: 0.6808 - val_mean_squared_error: 0.7788
# Epoch 262/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5716 - mean_squared_error: 0.5836 - val_loss: 0.6976 - val_mean_squared_error: 0.8081
# Epoch 263/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5725 - mean_squared_error: 0.5839 - val_loss: 0.6960 - val_mean_squared_error: 0.7846
# Epoch 264/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5720 - mean_squared_error: 0.5896 - val_loss: 0.6853 - val_mean_squared_error: 0.7863
# Epoch 265/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5726 - mean_squared_error: 0.5872 - val_loss: 0.7190 - val_mean_squared_error: 0.8058
# Epoch 266/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5715 - mean_squared_error: 0.5842 - val_loss: 0.6842 - val_mean_squared_error: 0.7732
# Epoch 267/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5721 - mean_squared_error: 0.5855 - val_loss: 0.7088 - val_mean_squared_error: 0.8122
# Epoch 268/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5725 - mean_squared_error: 0.5832 - val_loss: 0.7048 - val_mean_squared_error: 0.8161
# Epoch 269/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5706 - mean_squared_error: 0.5877 - val_loss: 0.7106 - val_mean_squared_error: 0.8278
# Epoch 270/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5729 - mean_squared_error: 0.5900 - val_loss: 0.7022 - val_mean_squared_error: 0.8453
# Epoch 271/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5709 - mean_squared_error: 0.5833 - val_loss: 0.6976 - val_mean_squared_error: 0.7966
# Epoch 272/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5704 - mean_squared_error: 0.5853 - val_loss: 0.6888 - val_mean_squared_error: 0.7860
# Epoch 273/2000
# 3432/3432 [==============================] - 0s 84us/step - loss: 0.5695 - mean_squared_error: 0.5817 - val_loss: 0.7098 - val_mean_squared_error: 0.8069
# Epoch 274/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5713 - mean_squared_error: 0.5881 - val_loss: 0.6928 - val_mean_squared_error: 0.7913
# Epoch 275/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5701 - mean_squared_error: 0.5820 - val_loss: 0.7026 - val_mean_squared_error: 0.8393
# Epoch 276/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5718 - mean_squared_error: 0.5834 - val_loss: 0.6956 - val_mean_squared_error: 0.7827
# Epoch 277/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5701 - mean_squared_error: 0.5847 - val_loss: 0.6959 - val_mean_squared_error: 0.7874
# Epoch 278/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5697 - mean_squared_error: 0.5815 - val_loss: 0.7044 - val_mean_squared_error: 0.8304
# Epoch 279/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5708 - mean_squared_error: 0.5864 - val_loss: 0.7030 - val_mean_squared_error: 0.7962
# Epoch 280/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5692 - mean_squared_error: 0.5803 - val_loss: 0.7152 - val_mean_squared_error: 0.8097
# Epoch 281/2000
# 3432/3432 [==============================] - 0s 66us/step - loss: 0.5702 - mean_squared_error: 0.5854 - val_loss: 0.7118 - val_mean_squared_error: 0.8382
# Epoch 282/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5684 - mean_squared_error: 0.5823 - val_loss: 0.6880 - val_mean_squared_error: 0.7741
# Epoch 283/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5699 - mean_squared_error: 0.5845 - val_loss: 0.7114 - val_mean_squared_error: 0.8599
# Epoch 284/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5701 - mean_squared_error: 0.5856 - val_loss: 0.6952 - val_mean_squared_error: 0.7637
# Epoch 285/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5703 - mean_squared_error: 0.5824 - val_loss: 0.7061 - val_mean_squared_error: 0.8381
# Epoch 286/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5704 - mean_squared_error: 0.5845 - val_loss: 0.7077 - val_mean_squared_error: 0.8599
# Epoch 287/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5677 - mean_squared_error: 0.5787 - val_loss: 0.7059 - val_mean_squared_error: 0.8053
# Epoch 288/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5667 - mean_squared_error: 0.5779 - val_loss: 0.7005 - val_mean_squared_error: 0.7850
# Epoch 289/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.5682 - mean_squared_error: 0.5808 - val_loss: 0.7121 - val_mean_squared_error: 0.8435
# Epoch 290/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5677 - mean_squared_error: 0.5799 - val_loss: 0.7131 - val_mean_squared_error: 0.7980
# Epoch 291/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5671 - mean_squared_error: 0.5783 - val_loss: 0.6883 - val_mean_squared_error: 0.7679
# Epoch 292/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5692 - mean_squared_error: 0.5810 - val_loss: 0.6991 - val_mean_squared_error: 0.8221
# Epoch 293/2000
# 3432/3432 [==============================] - 0s 67us/step - loss: 0.5680 - mean_squared_error: 0.5822 - val_loss: 0.7043 - val_mean_squared_error: 0.8319
# Epoch 294/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5683 - mean_squared_error: 0.5831 - val_loss: 0.6952 - val_mean_squared_error: 0.7946
# Epoch 295/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5672 - mean_squared_error: 0.5820 - val_loss: 0.7119 - val_mean_squared_error: 0.8751
# Epoch 296/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5683 - mean_squared_error: 0.5786 - val_loss: 0.7097 - val_mean_squared_error: 0.8440
# Epoch 297/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5678 - mean_squared_error: 0.5793 - val_loss: 0.7009 - val_mean_squared_error: 0.7962
# Epoch 298/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5669 - mean_squared_error: 0.5772 - val_loss: 0.6975 - val_mean_squared_error: 0.8290
# Epoch 299/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5686 - mean_squared_error: 0.5873 - val_loss: 0.6837 - val_mean_squared_error: 0.7650
# Epoch 300/2000
# 3432/3432 [==============================] - 0s 82us/step - loss: 0.5692 - mean_squared_error: 0.5829 - val_loss: 0.7087 - val_mean_squared_error: 0.8178
# Epoch 301/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5682 - mean_squared_error: 0.5832 - val_loss: 0.6974 - val_mean_squared_error: 0.8232
# Epoch 302/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5683 - mean_squared_error: 0.5784 - val_loss: 0.6877 - val_mean_squared_error: 0.7812
# Epoch 303/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5672 - mean_squared_error: 0.5805 - val_loss: 0.7170 - val_mean_squared_error: 0.7952
# Epoch 304/2000
# 3432/3432 [==============================] - 0s 78us/step - loss: 0.5697 - mean_squared_error: 0.5836 - val_loss: 0.7011 - val_mean_squared_error: 0.8038
# Epoch 305/2000
# 3432/3432 [==============================] - 0s 78us/step - loss: 0.5687 - mean_squared_error: 0.5837 - val_loss: 0.6967 - val_mean_squared_error: 0.8125
# Epoch 306/2000
# 3432/3432 [==============================] - 0s 76us/step - loss: 0.5655 - mean_squared_error: 0.5813 - val_loss: 0.7147 - val_mean_squared_error: 0.8101
# Epoch 307/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5668 - mean_squared_error: 0.5797 - val_loss: 0.7006 - val_mean_squared_error: 0.8164
# Epoch 308/2000
# 3432/3432 [==============================] - 0s 81us/step - loss: 0.5686 - mean_squared_error: 0.5808 - val_loss: 0.6993 - val_mean_squared_error: 0.8369
# Epoch 309/2000
# 3432/3432 [==============================] - 0s 89us/step - loss: 0.5666 - mean_squared_error: 0.5761 - val_loss: 0.7019 - val_mean_squared_error: 0.7978
# Epoch 310/2000
# 3432/3432 [==============================] - 0s 78us/step - loss: 0.5652 - mean_squared_error: 0.5781 - val_loss: 0.6887 - val_mean_squared_error: 0.7756
# Epoch 311/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5661 - mean_squared_error: 0.5759 - val_loss: 0.7137 - val_mean_squared_error: 0.8445
# Epoch 312/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5693 - mean_squared_error: 0.5798 - val_loss: 0.7030 - val_mean_squared_error: 0.7868
# Epoch 313/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5666 - mean_squared_error: 0.5842 - val_loss: 0.7033 - val_mean_squared_error: 0.8453
# Epoch 314/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5682 - mean_squared_error: 0.5812 - val_loss: 0.6985 - val_mean_squared_error: 0.7907
# Epoch 315/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5660 - mean_squared_error: 0.5772 - val_loss: 0.6852 - val_mean_squared_error: 0.7731
# Epoch 316/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5675 - mean_squared_error: 0.5762 - val_loss: 0.7106 - val_mean_squared_error: 0.8130
# Epoch 317/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5676 - mean_squared_error: 0.5831 - val_loss: 0.7096 - val_mean_squared_error: 0.8535
# Epoch 318/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5657 - mean_squared_error: 0.5759 - val_loss: 0.6982 - val_mean_squared_error: 0.8219
# Epoch 319/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5658 - mean_squared_error: 0.5773 - val_loss: 0.6857 - val_mean_squared_error: 0.7991
# Epoch 320/2000
# 3432/3432 [==============================] - 0s 82us/step - loss: 0.5651 - mean_squared_error: 0.5826 - val_loss: 0.6972 - val_mean_squared_error: 0.7791
# Epoch 321/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5653 - mean_squared_error: 0.5779 - val_loss: 0.6895 - val_mean_squared_error: 0.8102
# Epoch 322/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.5649 - mean_squared_error: 0.5728 - val_loss: 0.7034 - val_mean_squared_error: 0.8404
# Epoch 323/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5651 - mean_squared_error: 0.5723 - val_loss: 0.6949 - val_mean_squared_error: 0.8148
# Epoch 324/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5677 - mean_squared_error: 0.5759 - val_loss: 0.6941 - val_mean_squared_error: 0.7904
# Epoch 325/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5648 - mean_squared_error: 0.5756 - val_loss: 0.6952 - val_mean_squared_error: 0.7891
# Epoch 326/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5638 - mean_squared_error: 0.5762 - val_loss: 0.6926 - val_mean_squared_error: 0.7741
# Epoch 327/2000
# 3432/3432 [==============================] - 0s 79us/step - loss: 0.5658 - mean_squared_error: 0.5810 - val_loss: 0.7072 - val_mean_squared_error: 0.8367
# Epoch 328/2000
# 3432/3432 [==============================] - 0s 82us/step - loss: 0.5657 - mean_squared_error: 0.5779 - val_loss: 0.6991 - val_mean_squared_error: 0.7980
# Epoch 329/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5658 - mean_squared_error: 0.5781 - val_loss: 0.7528 - val_mean_squared_error: 0.8687
# Epoch 330/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5654 - mean_squared_error: 0.5770 - val_loss: 0.7099 - val_mean_squared_error: 0.8452
# Epoch 331/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5641 - mean_squared_error: 0.5734 - val_loss: 0.6995 - val_mean_squared_error: 0.7938
# Epoch 332/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5653 - mean_squared_error: 0.5799 - val_loss: 0.7136 - val_mean_squared_error: 0.7879
# Epoch 333/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5652 - mean_squared_error: 0.5754 - val_loss: 0.7287 - val_mean_squared_error: 0.9172
# Epoch 334/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5656 - mean_squared_error: 0.5793 - val_loss: 0.7156 - val_mean_squared_error: 0.8834
# Epoch 335/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5650 - mean_squared_error: 0.5725 - val_loss: 0.6998 - val_mean_squared_error: 0.8057
# Epoch 336/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5641 - mean_squared_error: 0.5723 - val_loss: 0.7121 - val_mean_squared_error: 0.8062
# Epoch 337/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5633 - mean_squared_error: 0.5733 - val_loss: 0.6847 - val_mean_squared_error: 0.7757
# Epoch 338/2000
# 3432/3432 [==============================] - 0s 66us/step - loss: 0.5648 - mean_squared_error: 0.5750 - val_loss: 0.6965 - val_mean_squared_error: 0.8014
# Epoch 339/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5631 - mean_squared_error: 0.5714 - val_loss: 0.7067 - val_mean_squared_error: 0.8118
# Epoch 340/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5624 - mean_squared_error: 0.5692 - val_loss: 0.6808 - val_mean_squared_error: 0.7712
# Epoch 341/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5642 - mean_squared_error: 0.5737 - val_loss: 0.7117 - val_mean_squared_error: 0.8560
# Epoch 342/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5634 - mean_squared_error: 0.5762 - val_loss: 0.6963 - val_mean_squared_error: 0.8263
# Epoch 343/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5639 - mean_squared_error: 0.5757 - val_loss: 0.6857 - val_mean_squared_error: 0.7700
# Epoch 344/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5641 - mean_squared_error: 0.5788 - val_loss: 0.7053 - val_mean_squared_error: 0.7931
# Epoch 345/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5637 - mean_squared_error: 0.5742 - val_loss: 0.6928 - val_mean_squared_error: 0.7732
# Epoch 346/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5632 - mean_squared_error: 0.5703 - val_loss: 0.7129 - val_mean_squared_error: 0.8300
# Epoch 347/2000
# 3432/3432 [==============================] - 0s 71us/step - loss: 0.5633 - mean_squared_error: 0.5780 - val_loss: 0.7094 - val_mean_squared_error: 0.8479
# Epoch 348/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5623 - mean_squared_error: 0.5709 - val_loss: 0.7078 - val_mean_squared_error: 0.8249
# Epoch 349/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5628 - mean_squared_error: 0.5712 - val_loss: 0.7273 - val_mean_squared_error: 0.8156
# Epoch 350/2000
# 3432/3432 [==============================] - 0s 80us/step - loss: 0.5630 - mean_squared_error: 0.5764 - val_loss: 0.6896 - val_mean_squared_error: 0.7928
# Epoch 351/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5641 - mean_squared_error: 0.5808 - val_loss: 0.6954 - val_mean_squared_error: 0.7956
# Epoch 352/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5649 - mean_squared_error: 0.5763 - val_loss: 0.7001 - val_mean_squared_error: 0.7925
# Epoch 353/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5653 - mean_squared_error: 0.5807 - val_loss: 0.7303 - val_mean_squared_error: 0.9132
# Epoch 354/2000
# 3432/3432 [==============================] - 0s 75us/step - loss: 0.5644 - mean_squared_error: 0.5746 - val_loss: 0.7087 - val_mean_squared_error: 0.8096
# Epoch 355/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5641 - mean_squared_error: 0.5771 - val_loss: 0.6985 - val_mean_squared_error: 0.7902
# Epoch 356/2000
# 3432/3432 [==============================] - 0s 77us/step - loss: 0.5616 - mean_squared_error: 0.5733 - val_loss: 0.6973 - val_mean_squared_error: 0.7978
# Epoch 357/2000
# 3432/3432 [==============================] - 0s 74us/step - loss: 0.5611 - mean_squared_error: 0.5746 - val_loss: 0.6974 - val_mean_squared_error: 0.7938
# Epoch 358/2000
# 3432/3432 [==============================] - 0s 69us/step - loss: 0.5605 - mean_squared_error: 0.5719 - val_loss: 0.7133 - val_mean_squared_error: 0.8764
# Epoch 359/2000
# 3432/3432 [==============================] - 0s 73us/step - loss: 0.5625 - mean_squared_error: 0.5733 - val_loss: 0.7100 - val_mean_squared_error: 0.8620
# Epoch 360/2000
# 3432/3432 [==============================] - 0s 70us/step - loss: 0.5616 - mean_squared_error: 0.5730 - val_loss: 0.7058 - val_mean_squared_error: 0.7912
# Epoch 361/2000
# 3432/3432 [==============================] - 0s 68us/step - loss: 0.5630 - mean_squared_error: 0.5762 - val_loss: 0.7039 - val_mean_squared_error: 0.8048
# Epoch 362/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5618 - mean_squared_error: 0.5731 - val_loss: 0.7322 - val_mean_squared_error: 0.9280
# Epoch 363/2000
# 3432/3432 [==============================] - 0s 82us/step - loss: 0.5612 - mean_squared_error: 0.5708 - val_loss: 0.7011 - val_mean_squared_error: 0.8121
# Epoch 364/2000
# 3432/3432 [==============================] - 0s 72us/step - loss: 0.5611 - mean_squared_error: 0.5709 - val_loss: 0.7172 - val_mean_squared_error: 0.8588
# 3432/3432 [==============================] - 2s 444us/step
# Score: loss of 0.589273878466555; mean_squared_error of 60.581095068604796%

# %% [markdown]
# ### Examine the results

# %%
# run the training dataset back through the netowrk to show how well it can match its traing values over calibration data (comp vs obs)    # this is a first order 

#### All plots
fig2, ax = plt.subplots(1, 3, figsize=(9, 3))

######## plot 1 to 1 for # view results of predictions on the calibration data 
y_pred_calibration = model.predict(X_train)
y_pred_calibration = y_train_scaler.inverse_transform(y_pred_calibration)    # unscale the final data baed on the scaler from the initial scaling cell abovee

xcal = np.squeeze(train_data[y_col].values)
ycal = np.squeeze(y_pred_calibration)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(xcal, ycal)                              # get stats on regression
mea = np.mean(np.abs(xcal-ycal))
rmse = np.sqrt(np.mean(np.abs(xcal-ycal)**2))                                     # couple more basic stats on the residuals, Mean absolute errir and root RMSE root mean squared error
Std_RMSE = rmse/((np.mean(xcal)+np.mean(ycal))/2)                                 # standardize the RMSE as a % of the mean
ax[0].plot(np.unique(xcal), np.poly1d(np.polyfit(xcal, ycal, 1))(np.unique(xcal)),  color = 'k', linestyle = "--")    # plot the linear regresion line 
ax[0].scatter(xcal, ycal, label="r2={0:1.2f}, slope={1:1.2f}\nRMSE={2:1.2f} S_RMSE={3:1.2f}".format(r_value, slope, rmse, Std_RMSE))   
ax[0].set_title('Actual vs simulated data Calibration')
ax[0].legend()

###### Plot losses
ax[1].set_title('Loss vs. Epoch')
ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])

###### plot 1 to 1 for # view results of predictions on the validation data 
y_pred_validation = model.predict(X_val)
y_pred_validation = y_val_scaler.inverse_transform(y_pred_validation)    # unscale the final data baed on the scaler from the initial scaling cell abovee

xval = np.squeeze(val_data[y_col].values)
yval = np.squeeze(y_pred_validation)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(xval, yval)                              # get stats on regression
mea = np.mean(np.abs(xval-yval))
rmse = np.sqrt(np.mean(np.abs(xval-yval)**2))                                     # couple more basic stats on the residuals, Mean absolute errir and root RMSE root mean squared error
Std_RMSE = rmse/((np.mean(xval)+np.mean(yval))/2)                                 # standardize the RMSE as a % of the mean
ax[2].plot(np.unique(xval), np.poly1d(np.polyfit(xval, yval, 1))(np.unique(xval)),  color = 'k', linestyle = "--")    # plot the linear regresion line 
ax[2].scatter(xval, yval, label="r2={0:1.2f}, slope={1:1.2f}\nRMSE={2:1.2f} S_RMSE={3:1.2f}".format(r_value, slope, rmse, Std_RMSE))   
ax[2].set_title('Actual vs simulated data Validation')
ax[2].legend()

##### time series plot
plt.figure(figsize=(12, 4))
plt.plot(train_data.index, ycal, label='Predicted')
train_data[y_col].plot(label='Actual', alpha = .5)
plt.plot(val_data.index, yval, label='Predicted')
val_data[y_col].plot(label='Actual', alpha = .5)
plt.legend(loc='best')

# %% [markdown]
# ### Compare to simply gap filling with the mean

# %%
# run the training dataset back through the netowrk to show how well it can match its traing values over calibration data (comp vs obs)    # this is a first order 

#### All plots
fig2, ax = plt.subplots(1, 1, figsize=(3, 3))

###### plot 1 to 1 for # view results of predictions on the validation data 
y_pred_validation = np.full(np.shape(y_val), y_val.mean())
y_pred_validation = y_val_scaler.inverse_transform(y_pred_validation)    # unscale the final data baed on the scaler from the initial scaling cell abovee

xval = np.squeeze(val_data[y_col].values)
yval = np.squeeze(y_pred_validation)
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(xval, yval)                              # get stats on regression
mea = np.mean(np.abs(xval-yval))
rmse = np.sqrt(np.mean(np.abs(xval-yval)**2))                                     # couple more basic stats on the residuals, Mean absolute errir and root RMSE root mean squared error
Std_RMSE = rmse/((np.mean(xval)+np.mean(yval))/2)                                 # standardize the RMSE as a % of the mean
ax.plot(np.unique(xval), np.poly1d(np.polyfit(xval, yval, 1))(np.unique(xval)),  color = 'k', linestyle = "--")    # plot the linear regresion line 
ax.scatter(xval, yval, label="r2={0:1.2f}, slope={1:1.2f}\nRMSE={2:1.2f} S_RMSE={3:1.2f}".format(r_value, slope, rmse, Std_RMSE))   
ax.set_title('Actual vs simulated data Validation')
ax.legend()

##### time series plot
plt.figure(figsize=(12, 4))
plt.plot(train_data.index, ycal, label='Predicted')
train_data[y_col].plot(label='Actual', alpha = .5)
plt.plot(val_data.index, yval, label='Predicted')
val_data[y_col].plot(label='Actual', alpha = .5)
plt.legend(loc='best')

# %% [markdown]
# # Use the model, fill the gaps
# even though the model is un-ideal at the moment....
# On issue to fix someday is that the absolute magnitudes of the data don't get quite up to par (the slope is under predicted...)

# %%
# Set up the gap filling by definging datasets and IDing the series needeing filling.

magic_data = dataset_cleanish.copy()
all_cols = list(magic_data.columns)
train_data_all = unbroken_data

# this bit makes a list of the variable that need some filling. (1 or > gaps) 
broken_vars = []
for var in all_cols:
    wha = find_date_gaps(dataset_cleanish, var)
    
    if wha[0]:                   # this means if the gap start lists are not empty
        broken_vars.append(var)  # make the list of broken variables
# Out:
# gap 0 is 427 days 00:00:00 from 2011-10-01 00:00:00 to 2012-12-01 00:00:00
# gap 0 is 365 days 00:00:00 from 2015-01-01 00:00:00 to 2016-01-01 00:00:00

# %% [markdown]
# ### Monster loop to fill all the gaps!
#
# note this doesn't work if there are overlapping gaps ( to get around an overlappig 5 day gap I had to extend the mean fill period to 7 days, not the best...

# %%
magic_data = dataset_cleanish.copy()
YScaler_dic = {}; XScaler_dic = {}

for i in broken_vars:
    x_cols = ['AWND', 'PRCP', 'TMAX', 'TMIN', 'RH_pct']
    x_cols.remove(i)                                     # remove the param of interest
    y_col = i

    # set up the training datasets
    X_train = train_data_all[x_cols].values  
    # scale the x component of the training data
    XScaler_dic[i] = StandardScaler().fit(X_train)
    X_train =  XScaler_dic[i].transform(X_train)
    y_train = train_data_all[y_col].values                 
    # scale the y data too, and then make the scale unique to use it to unscale the final data later
    y_train = y_train.reshape(-1, 1)
    YScaler_dic[i] = StandardScaler().fit(y_train)
    y_train = YScaler_dic[i].transform(y_train) 
    
# set up the DL network     
    model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
    model = define_model_dense(hidden_layer_sizes, input_shape, activation, optimizer)

    
# train the network
    # Note using callbacks from ( https://www.machinecurve.com/index.php/2019/05/30/avoid-wasting-resources-with-earlystopping-and-modelcheckpoint-in-keras/ )
    checkpoint_path = os.path.join(os.getcwd(), 'testmodel_random_callback_save.h5')
    keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=30, mode='min', min_delta=0.001),
                         ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')]

    history = model.fit(X_train, y_train, epochs=2000,verbose=0, validation_data =(X_val,  y_val), callbacks=keras_callbacks)

    # load the best saved model based on validation loss
    model = load_model(checkpoint_path)
    scores = model.evaluate(X_train, y_train, verbose=1)
    print(f'Score: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    
# fill the gaps 
    Strt_gp, End_gp = find_date_gaps(magic_data, i)                         # define all the existing gaps
    
    for idx, val in enumerate(Strt_gp):                                     # for each gap
        X_fill = magic_data[x_cols].loc[Strt_gp[idx]:End_gp[idx]].values    # existing data in other columns 
        # scale the x component of the fill data
        X_fill =  XScaler_dic[i].transform(X_fill)                           # scale existing data in other columns  
        y_pred_fill = model.predict(X_fill)                                 # use the network to generate predicted valued for desired column
        
        y_pred_fill = YScaler_dic[i].inverse_transform(y_pred_fill)    # unscale the final data baed on the scaler from the initial scaling cell above (have to use dictionary of scalers to make sure each col is scaled right)

        # replace the gap with predicted data!
        magic_data['{}_filled'.format(i)] = magic_data[i]
        magic_data['{}_filled'.format(i)].loc[Strt_gp[idx]:End_gp[idx]] = np.squeeze(y_pred_fill)       
        
magic_data.plot(figsize = (12, 5), alpha = .7)
magic_data.to_csv(os.path.join(workspace, "Magic_gap_filled_PPG_data.csv"))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 12)                60
# _________________________________________________________________
# dense_6 (Dense)              (None, 80)                1040
# _________________________________________________________________
# dense_7 (Dense)              (None, 80)                6480
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 81
# =================================================================
# Total params: 7,661
# Trainable params: 7,661
# Non-trainable params: 0
# _________________________________________________________________
# 4291/4291 [==============================] - 0s 31us/step
# Score: loss of 0.8463730927364889; acc of 0.0%
# gap 0 is 427 days 00:00:00 from 2011-10-01 00:00:00 to 2012-12-01 00:00:00
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 12)                60
# _________________________________________________________________
# dense_10 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_11 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,661
# Trainable params: 7,661
# Non-trainable params: 0
# _________________________________________________________________
# 4291/4291 [==============================] - 0s 42us/step
# Score: loss of 0.6930049663655715; acc of 0.0%
# gap 0 is 365 days 00:00:00 from 2015-01-01 00:00:00 to 2016-01-01 00:00:00

# %% [markdown]
# # Now load in other datasets  from other weather stations

# %% [markdown]
# ### Pull UH-ASPA data off of my GitHub site
# note, reflects most recent update of processed data, not raw data

# %%
url = "https://raw.githubusercontent.com/cshuler/ASPA-UH_Integrated_Modeling_Framework/master/ASPA-UH_Wx_REPO/workspace/QA_All_merged.csv"
save_to = os.path.join("..", 'Data', "All_consolodated_Q_m3ps.csv")

r = requests.get(url, allow_redirects=True)
open(save_to, 'wb').write(r.content)
# Out:
# 16346953

# %% [markdown]
# #### get the data into memory

# %%
rawdata = pd.read_csv(save_to ,index_col=1,parse_dates=True)   # read in data
rawdata = rawdata.drop(rawdata.columns[0], axis=1)             # get rid of pesky index column

param_list =  ['SRD_wpm2', 'HMD_pct', 'TMP_F', 'RNF_in', 'WND_deg', 'WNS_mph']

ASPA_param_dic = {}
for q in param_list: 
    r = re.compile(".*{}".format(q))  
    Col_list = list(filter(r.match, list(rawdata.columns)))
    tempframe = rawdata[Col_list]
    ASPA_param_dic[q] = tempframe
    
# resample the rainfall to hourly values using a sum method
ASPA_param_dic['RNF_in'] = ASPA_param_dic['RNF_in'].resample('D').sum()     # subsample the 15 min data into daily values
# resample all others to hourly values using a average method
ave_param_list = ['SRD_wpm2', 'HMD_pct', 'TMP_F', 'WND_deg', 'WNS_mph'] 
for i in ave_param_list:
    ASPA_param_dic[i] = ASPA_param_dic[i].resample('D').mean()     # subsample the 15 min data into daily values

# Exoloratory Plot  All the datasets 
for i in param_list: 
    ASPA_param_dic[i].plot(subplots=True, figsize=(12, 8))
    plt.tight_layout()
    plt.legend(loc='best')

# %% [markdown]
# # Tula Data
# From Tula weather station, pre-downloaded and living in a file folder, Tula site is: https://www.esrl.noaa.gov/gmd/obop/smo/
#
# ### careful, long run time

# %%
# processing Tula data into a single dataframe
path_Tula_data = os.path.join("..", "Data", 'External_weather_data', 'Tula', "Met")

trash_cols = ['SITE CODE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'WND', 'WNS_mpsec', 'WND_STEADY', 'BAR_p', 'TMP_2m', 'TMP_10m', 'TMP_top', 'HMD', 'PRECIP_mm']
want_cols = ['Date', 'PRECIP_mm', 'HMD', 'TMP_2m', 'WND', 'WNS_mpsec']

files = os.listdir(path_Tula_data)                     # get all file names in the folder
na_values = ['-99', '-9', '-999', '-99.9', '-999.9']   #values to turn into NaN 
temp_data =  pd.DataFrame(columns=trash_cols)          # empty container for concat

for i in files: 
    q = pd.read_csv(os.path.join(path_Tula_data, i), delim_whitespace=True, names=trash_cols, na_values=na_values) # open each file
    temp_data = pd.concat([temp_data, q], axis=0)     # stick em all together

temp_data['Date'] = temp_data[['YEAR', 'MONTH', 'DAY', 'HOUR']].apply(lambda x : datetime(*x),axis = 1)  # make the date a date
tula_data2 = temp_data[want_cols].set_index("Date") 

tula_data2['HMD'] = tula_data2['HMD'].apply(lambda x: 100 if x >99.9  else x) #Wtf?  Why are rel HMD values greater than 100%? fix this with some comon sense

# Now resampling data into neeed formats   this is set up for daily resampling 
tula_data2['Tmp_max'] = tula_data2['TMP_2m']                   # just make the columns get ready for resampling
tula_data2['Tmp_min'] = tula_data2['TMP_2m']                  # just make the columns get ready for resampling
tula_data2 = tula_data2.rename(columns={'TMP_2m': 'TMP_ave'})  # just make the columns get ready for resampling

tula_data_rn = tula_data2['PRECIP_mm'].resample('D').sum()      # resample the rain different than the other columns
tula_data_tmax = tula_data2['Tmp_max'].resample('D').max()      # resample the tmax different than the other columns
tula_data_tmin = tula_data2['Tmp_min'].resample('D').min()      # resample the tmin different than the other columns
tula_data_others = tula_data2[['HMD', 'TMP_ave', 'WND', 'WNS_mpsec']].resample('D').mean()   
Tula_data = tula_data_others.join(tula_data_rn)                 #merge tehm back together
Tula_data = Tula_data.join(tula_data_tmin)                 #merge tehm back together
Tula_data = Tula_data.join(tula_data_tmax)                 #merge tehm back together

# unit conversions
Tula_data['RNF_in'] =  Tula_data['PRECIP_mm'].apply(lambda x: x*0.0393701)     # convert rain in mm to rain in inches
Tula_data['TMP_ave_F'] =  Tula_data['TMP_ave'].apply(lambda x: x*1.8 + 32)     # convert rain in mm to rain in inches
Tula_data['TMP_max_F'] =  Tula_data['Tmp_max'].apply(lambda x: x*1.8 + 32)     # convert rain in mm to rain in inches
Tula_data['Tmp_min_F'] =  Tula_data['Tmp_min'].apply(lambda x: x*1.8 + 32)     # convert rain in mm to rain in inches
Tula_data['WNS_mph'] =  Tula_data['WNS_mpsec'].apply(lambda x: x*2.23694)     # convert rain in mm to rain in inches
del Tula_data['WNS_mpsec']; del Tula_data['TMP_ave']; del Tula_data['PRECIP_mm']; del Tula_data['Tmp_max']; del Tula_data['Tmp_min']

# this block is to deal with the separate solar radiation (SLR )files
Path_go_SLR = os.path.join("..", "Data", 'External_weather_data', 'Tula', 'Slr') 

trash_cols = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'MIN', 'DIRECT', 'DIFFUSE2', 'D_GLOBAL', 'D_IR', 'Zenith']
want_cols = ["Date", "DIRECT"]

SLR_files = os.listdir(Path_go_SLR)                     # get all file names in the folder
na_values = ['-99', '-9', '-999', '-99.9', '-999.9']   #values to turn into NaN 

temp_data =  pd.DataFrame(columns=trash_cols)          # empty container for concat
for i in SLR_files: 
    q = pd.read_csv(os.path.join(Path_go_SLR, i), delim_whitespace=True, skiprows= range(0,4), names=trash_cols,  na_values=na_values) # open each file     
    temp_data = pd.concat([temp_data, q], axis=0)     # stick em all together

temp_data['Date'] = temp_data[['YEAR', 'MONTH', 'DAY', 'HOUR', 'MIN']].apply(lambda x : datetime(*x),axis = 1)  # make the date a date
tula_SLR2 = temp_data[want_cols].set_index("Date") 
tula_data_SLR = tula_SLR2['DIRECT'].resample('D').mean()      # resample the rain different than the other columns

Tula_data = Tula_data.join(tula_data_SLR)        
Tula_data = Tula_data.rename(columns={'DIRECT': 'SLR_wpm2'})

# this block deals with the fup that the station was obviously down but recording 0s for some periods. 
en10 = int(len(Tula_data)/10)                      # make the acceptable window of days without rain at 10 days.
s = 0; e = 9
for i in range(0,10):
    if Tula_data['RNF_in'].iloc[s:e].sum() == 0:   # if the drought is more than 10 days long the sensor was bad so change values to nan
        Tula_data['RNF_in'].iloc[s:e] = np.nan
    s+=10; e+=10

# clear up these columns temporarily while I dont care abot these columns 
del Tula_data['WND']
del Tula_data['SLR_wpm2']
del Tula_data['TMP_ave_F']

# %%
Tula_data.plot(alpha=.5, figsize = (12,3))
Tula_data
# Out:
#                   HMD    RNF_in  TMP_max_F  Tmp_min_F    WNS_mph
# Date
# 2015-01-01  86.416667  0.944882      83.66      77.72  12.275208
# 2015-01-02  85.166667  0.118110      90.86      79.52   5.638953
# 2015-01-03  84.000000  0.157480      88.52      76.10  13.645334
# 2015-01-04  83.000000  0.039370      92.84      80.24   9.954383
# 2015-01-05  84.666667  2.401576      91.40      78.62   9.861177
# ...               ...       ...        ...        ...        ...
# 2019-09-26  92.125000  0.000000      85.82      77.54  17.159194
# 2019-09-27  86.375000  0.000000      85.46      79.34  20.906068
# 2019-09-28  84.166667  0.000000      85.28      78.08  23.991182
# 2019-09-29  81.750000  0.000000      86.54      78.44  20.290910
# 2019-09-30  82.450000  0.000000      86.00      79.88  24.617525
#
# [1734 rows x 5 columns]

# %% [markdown]
# # Processing historical ASCC data obtained from Mark

# %%
path_ASCC_data_old =  os.path.join("..", "Data", 'External_weather_data', 'ASCC', 'GroWeatherData 2004-2014.csv')
ASCC_All = pd.read_csv(os.path.join(path_ASCC_data_old), parse_dates=[['Date', 'Time']],  keep_date_col=True,  usecols = [0,1, 2, 8, 12, 14, 17, 19], na_values = ["--", "---"])

# clean data
ASCC_All['Date_Time'] = pd.to_datetime(ASCC_All['Date_Time'], errors='coerce')
del ASCC_All['Date']
del ASCC_All['Time']
numcols = ['Air Temp', 'Solar Rad', 'Wind Speed', 'Rain', 'Hum']
for i in numcols:
    ASCC_All[i] = pd.to_numeric(ASCC_All[i], errors='coerce')
ASCC_All = ASCC_All.set_index('Date_Time')

#resample daily 
ASCC_All['Tmp_max'] = ASCC_All['Air Temp']                   # just make the columns get ready for resampling
ASCC_All['Tmp_min'] = ASCC_All['Air Temp']                  # just make the columns get ready for resampling
ASCC_All = ASCC_All.rename(columns={'Air Temp': 'TMP_ave'})  # just make the columns get ready for resampling

ASCC_day_rain = ASCC_All['Rain'].resample('D').sum()     # sum the rainfall by days
ASCC_day_tmax = ASCC_All['Tmp_max'].resample('D').max()      # resample the tmax different than the other columns
ASCC_day_tmin = ASCC_All['Tmp_min'].resample('D').min()      # resample the tmin different than the other columns
ASCC_day_others = ASCC_All[['TMP_ave', 'Solar Rad', 'Wind Speed', 'Hum']].resample('D').mean()   
ASCC_All = ASCC_day_others.join(ASCC_day_rain)                 #merge tehm back together
ASCC_All = ASCC_All.join(ASCC_day_tmax)                 #merge tehm back together
ASCC_All_daily = ASCC_All.join(ASCC_day_tmin)                 #merge tehm back together


# remove trash
ASCC_All_daily[ASCC_All_daily < 0] = np.nan
ASCC_All_daily = ASCC_All_daily.loc[:"2013-12-31"]     # remove trashy data at the end of the stations life

# Convert units 
ASCC_All_daily['Rain'] = ASCC_All_daily['Rain']*0.0393701   # convert mm to in.
ASCC_All_daily['Wind Speed'] = ASCC_All_daily['Wind Speed']*0.621371    # convert km/hr to mi/hr
ASCC_All_daily['Tmp_min'] = ASCC_All_daily['Tmp_min']*(9/5)+32    # convert km/hr to mi/hr
ASCC_All_daily['Tmp_max'] = ASCC_All_daily['Tmp_max']*(9/5)+32    # convert km/hr to mi/hr
ASCC_All_daily['TMP_ave'] = ASCC_All_daily['TMP_ave']*(9/5)+32    # convert km/hr to mi/hr

# distinguish old stion from new 
ASCC_All_daily_old = ASCC_All_daily


############  New station   ##################
# read in data from the new weather station.
path_ASCC_data_new =  os.path.join("..", "Data", 'External_weather_data', 'ASCC', 'ASCCWeatherData_2015-2018_direct.csv')
ASCC_All = pd.read_csv(os.path.join(path_ASCC_data_new), parse_dates=[['Date', 'Time']],  keep_date_col=True,  usecols = [0,1, 2, 5, 7, 8, 17, 19], na_values = ["--", "---"])

# clean data
ASCC_All['Date_Time'] = pd.to_datetime(ASCC_All['Date_Time'], errors='coerce')
del ASCC_All['Date']
del ASCC_All['Time']
ASCC_All = ASCC_All.rename(columns={'OutTemp':'Air Temp', 'HumOut':'Hum', 'SpeedWind':'Wind Speed', 'Rad.Solar':'Solar Rad'})
for i in numcols:
    ASCC_All[i] = pd.to_numeric(ASCC_All[i], errors='coerce')
ASCC_All = ASCC_All.set_index('Date_Time')

#resample daily 

ASCC_All['Tmp_max'] = ASCC_All['Air Temp']                   # just make the columns get ready for resampling
ASCC_All['Tmp_min'] = ASCC_All['Air Temp']                  # just make the columns get ready for resampling
ASCC_All = ASCC_All.rename(columns={'Air Temp': 'TMP_ave'})  # just make the columns get ready for resampling


ASCC_day_rain = ASCC_All['Rain'].resample('D').sum()     # sum the rainfall by days
ASCC_day_tmax = ASCC_All['Tmp_max'].resample('D').max()      # resample the tmax different than the other columns
ASCC_day_tmin = ASCC_All['Tmp_min'].resample('D').min()      # resample the tmin different than the other columns
ASCC_day_others = ASCC_All[['TMP_ave', 'Solar Rad', 'Wind Speed', 'Hum']].resample('D').mean()   
ASCC_All = ASCC_day_others.join(ASCC_day_rain)                 #merge tehm back together
ASCC_All = ASCC_All.join(ASCC_day_tmax)                 #merge tehm back together
ASCC_All_daily = ASCC_All.join(ASCC_day_tmin)                 #merge tehm back together

# Convert units 
ASCC_All_daily['Rain'] = ASCC_All_daily['Rain']*0.0393701   # convert mm to in.
ASCC_All_daily['Wind Speed'] = ASCC_All_daily['Wind Speed']*0.621371    # convert km/hr to mi/hr
ASCC_All_daily['Tmp_min'] = ASCC_All_daily['Tmp_min']*(9/5)+32    # convert km/hr to mi/hr
ASCC_All_daily['Tmp_max'] = ASCC_All_daily['Tmp_max']*(9/5)+32    # convert km/hr to mi/hr
ASCC_All_daily['TMP_ave'] = ASCC_All_daily['TMP_ave']*(9/5)+32    # convert km/hr to mi/hr

# distinguish old stion from new 
ASCC_All_daily_new = ASCC_All_daily

# merge old and new
ASCC_All_combined = pd.concat([ASCC_All_daily_old, ASCC_All_daily_new])

# %%
del ASCC_All_combined['TMP_ave']
del ASCC_All_combined['Solar Rad']

# %%
#fig, ax, = plt.subplots()
ASCC_All_combined.plot(figsize =(12,3))
ASCC_All_combined
# Out:
#             Wind Speed        Hum      Rain  Tmp_max  Tmp_min
# Date_Time
# 2004-08-26    1.123871  91.739130  0.000000    74.12    73.94
# 2004-08-27    3.194235  81.326389  0.031496    81.86    73.76
# 2004-08-28    2.914322  76.980296  0.000000    82.22    74.12
# 2004-08-29    2.312018  76.781250  0.000000    82.58    73.04
# 2004-08-30    2.455063  82.052083  0.110236    83.84    73.40
# ...                ...        ...       ...      ...      ...
# 2018-02-18    0.020712   7.916667  0.015748    86.90    76.46
# 2018-02-19    0.020712  13.656250  0.015748    87.26    76.10
# 2018-02-20    0.000000  12.208333  0.000000    87.44    76.28
# 2018-02-21    2.447296   2.375000  0.062992    86.72    75.92
# 2018-02-22    4.213616   1.000000  3.968506    81.86    75.38
#
# [4324 rows x 5 columns]

# %% [markdown]
# # Start the big fill

# %% [markdown]
# ### Fill in Tula dataset

# %%
Magic_Tula_data = Tula_data.copy()   # the end result container

Tula_cols = ['HMD',           'Tmp_min_F', 'TMP_max_F', 'RNF_in', 'WNS_mph']
PPG_cols  = ['RH_pct_filled', 'TMIN',    'TMAX',    'PRCP',   'AWND_filled']

# model checkpoint params  
checkpoint_path = os.path.join(workspace, 'testmodel_random_callback_save2.h5')
keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=15, mode='min', min_delta=0.01),
                     ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')]

for idx, tcol in enumerate(Tula_cols):
    print("working on filling {}".format(tcol))
    ppgcol = PPG_cols[idx]
    Tula_temp_frame = Tula_data[[tcol]]
    PPG_tempframe   = magic_data[[ppgcol]]

    # join the two colummns of same variable from different stations
    data = pd.merge(PPG_tempframe, Tula_temp_frame, how='inner', left_index=True, right_index=True)   # careful with the behavior of inner, seems to leave gaps with nan values but starts the frame where both datasets exist  which is what I want
    train_data = data.dropna()       # remove any rows where there is no data (a gap) 

    # define and scale each dataset
    X_train = train_data[ppgcol].values 
    X_train = X_train.reshape(-1, 1)
    X_train_scaler = StandardScaler().fit(X_train)
    X_train = X_train_scaler.transform(X_train)

    y_train = train_data[tcol].values                 # scale the y data too, and then make the scale unique to use it to unscale the final data later
    y_train = y_train.reshape(-1, 1)
    y_train_scaler = StandardScaler().fit(y_train)
    y_train = y_train_scaler.transform(y_train)

    #set up the network a-fresh
    model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
    model = define_model_dense(hidden_layer_sizes, 1, activation, optimizer)    # input shape of 1 since only training on one columns

    # train the network
    history = model.fit(X_train, y_train, epochs=2000,verbose=0, validation_split = .5, callbacks=keras_callbacks)

    ## load the best saved model based on validation loss
    model = load_model(checkpoint_path)
    scores = model.evaluate(X_train, y_train, verbose=0)
    print(f'Score: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')


    # now that we have the trained model, use it to predict parameter of interest. 
    X_fill = data[ppgcol].values 
    X_fill = X_fill.reshape(-1, 1)
    XScaler_dic[tcol] = StandardScaler().fit(X_fill)
    X_fill =  XScaler_dic[tcol].transform(X_fill)                       # scale existing data in other columns  
    y_pred_fill = model.predict(X_fill)                                 # use the network to generate predicted valued for desired column
    y_pred_fill = y_train_scaler.inverse_transform(y_pred_fill)         # rescale the data back to its real magnitudes

    generated_dataframe = pd.DataFrame(index = data.index, data = {"gendata":np.squeeze(y_pred_fill)})    
    generated_dataframe['real_data'] = data[tcol]

    # if the real series has a gap fill with generated data, if not use real data
    generated_dataframe['Magic_{}'.format(tcol)] = generated_dataframe.apply(
        lambda row: row['gendata'] if np.isnan(row['real_data']) else row['real_data'], axis=1)   

    # merge it in to the big dataset
    Magic_Tula_data['Magic_{}'.format(tcol)] = generated_dataframe['Magic_{}'.format(tcol)]
    
    # plot results
    fig, ax = plt.subplots(2, 1, figsize=(15, 6))
    ax[0].plot(Magic_Tula_data[tcol], color = 'grey')
    ax[0].set_title('Observed {} data'.format(tcol))
    ax[1].plot(Magic_Tula_data['Magic_{}'.format(tcol)], color = 'purple')
    ax[1].plot(Magic_Tula_data[tcol], color = 'grey')
    ax[1].set_title('Gap_filled {} data'.format(tcol))
# Out:
# working on filling HMD
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_77 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_78 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_79 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_80 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.6915921582313647; acc of 0.0%
# working on filling Tmp_min_F
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_82 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_83 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.6568118709778578; acc of 0.0%
# working on filling TMP_max_F
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_85 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_86 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_87 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_88 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.5010784165574189; acc of 0.0%
# working on filling RNF_in
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_89 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_90 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_91 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 1.0069907194190373; acc of 0.0%
# working on filling WNS_mph
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_93 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_94 (Dense)             (None, 80)                1040
# _________________________________________________________________
# dense_95 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_96 (Dense)             (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.2356972251358617; acc of 0.0%

# %%
Magic_Tula_data
# Out:
#                   HMD    RNF_in  ...  Magic_RNF_in  Magic_WNS_mph
# Date                             ...
# 2015-01-01  86.416667  0.944882  ...      0.944882      12.275208
# 2015-01-02  85.166667  0.118110  ...      0.118110       5.638953
# 2015-01-03  84.000000  0.157480  ...      0.157480      13.645334
# 2015-01-04  83.000000  0.039370  ...      0.039370       9.954383
# 2015-01-05  84.666667  2.401576  ...      2.401576       9.861177
# ...               ...       ...  ...           ...            ...
# 2019-09-26  92.125000  0.000000  ...      0.000000      17.159194
# 2019-09-27  86.375000  0.000000  ...      0.000000      20.906068
# 2019-09-28  84.166667  0.000000  ...      0.000000      23.991182
# 2019-09-29  81.750000  0.000000  ...      0.000000      20.290910
# 2019-09-30  82.450000  0.000000  ...      0.000000      24.617525
#
# [1734 rows x 10 columns]

# %%
Magic_Tula_data.plot(figsize = (12,4), alpha =.5)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
Magic_Tula_data
# Out:
#                   HMD    RNF_in  ...  Magic_RNF_in  Magic_WNS_mph
# Date                             ...
# 2015-01-01  86.416667  0.944882  ...      0.944882      12.275208
# 2015-01-02  85.166667  0.118110  ...      0.118110       5.638953
# 2015-01-03  84.000000  0.157480  ...      0.157480      13.645334
# 2015-01-04  83.000000  0.039370  ...      0.039370       9.954383
# 2015-01-05  84.666667  2.401576  ...      2.401576       9.861177
# ...               ...       ...  ...           ...            ...
# 2019-09-26  92.125000  0.000000  ...      0.000000      17.159194
# 2019-09-27  86.375000  0.000000  ...      0.000000      20.906068
# 2019-09-28  84.166667  0.000000  ...      0.000000      23.991182
# 2019-09-29  81.750000  0.000000  ...      0.000000      20.290910
# 2019-09-30  82.450000  0.000000  ...      0.000000      24.617525
#
# [1734 rows x 10 columns]

# %%
ASCC_All_combined.columns
# Out:
# Index(['Wind Speed', 'Hum', 'Rain', 'Tmp_max', 'Tmp_min'], dtype='object')

# %%
Magic_ASCC_data = ASCC_All_combined.copy()   # the end result container

ASCC_cols = ['Hum',           'Tmp_min', 'Tmp_max', 'Rain', 'Wind Speed']
PPG_cols  = ['RH_pct_filled', 'TMIN',    'TMAX',    'PRCP',   'AWND_filled']

# model checkpoint params  
checkpoint_path = os.path.join(workspace, 'testmodel_random_callback_save2.h5')
keras_callbacks   = [EarlyStopping(monitor='val_loss', patience=15, mode='min', min_delta=0.01),
                     ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')]

for idx, tcol in enumerate(ASCC_cols):
    print("working on filling {}".format(tcol))
    ppgcol = PPG_cols[idx]
    ASCC_temp_frame = ASCC_All_combined[[tcol]].copy()
    PPG_tempframe   = magic_data[[ppgcol]]

    # join the two colummns of same variable from different stations
    data = pd.merge(PPG_tempframe, ASCC_temp_frame, how='inner', left_index=True, right_index=True)   # careful with the behavior of inner, seems to leave gaps with nan values but starts the frame where both datasets exist  which is what I want
    train_data = data.dropna()       # remove any rows where there is no data (a gap) 

    # define and scale each dataset
    X_train = train_data[ppgcol].values 
    X_train = X_train.reshape(-1, 1)
    X_train_scaler = StandardScaler().fit(X_train)
    X_train = X_train_scaler.transform(X_train)

    y_train = train_data[tcol].values                 # scale the y data too, and then make the scale unique to use it to unscale the final data later
    y_train = y_train.reshape(-1, 1)
    y_train_scaler = StandardScaler().fit(y_train)
    y_train = y_train_scaler.transform(y_train)

    #set up the network a-fresh
    model = "reset"; del model   # redefine, then delete model to make sure previous model weights are DESTROIED!
    model = define_model_dense(hidden_layer_sizes, 1, activation, optimizer)    # input shape of 1 since only training on one columns

    # train the network
    history = model.fit(X_train, y_train, epochs=2000,verbose=0, validation_split = .5, callbacks=keras_callbacks)

    ## load the best saved model based on validation loss
    model = load_model(checkpoint_path)
    scores = model.evaluate(X_train, y_train, verbose=0)
    print(f'Score: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')

    # now that we have the trained model, use it to predict parameter of interest. 
    X_fill = data[ppgcol].values 
    X_fill = X_fill.reshape(-1, 1)
    XScaler_dic[tcol] = StandardScaler().fit(X_fill)
    X_fill =  XScaler_dic[tcol].transform(X_fill)                       # scale existing data in other columns  
    y_pred_fill = model.predict(X_fill)                                 # use the network to generate predicted valued for desired column
    y_pred_fill = y_train_scaler.inverse_transform(y_pred_fill)         # rescale the data back to its real magnitudes

    generated_dataframe = pd.DataFrame(index = data.index, data = {"gendata":np.squeeze(y_pred_fill)})    
    generated_dataframe['real_gap_data'] = data[tcol]

    # if the real series has a gap fill with generated data, if not use real data
    generated_dataframe['Magic_{}'.format(tcol)] = generated_dataframe.apply(
        lambda row: row['gendata'] if np.isnan(row['real_gap_data']) else row['real_gap_data'], axis=1)   

    # merge it in to the big dataset
    Magic_ASCC_data['Magic_{}'.format(tcol)] = generated_dataframe['Magic_{}'.format(tcol)]
    
    generated_dataframe.plot(figsize = (12,4), alpha=.5)
# Out:
# working on filling Hum
# Model: "sequential_100"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_424 (Dense)            (None, 12)                24
# _________________________________________________________________
# dense_425 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_426 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_427 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 1.0791583080750762; acc of 0.0%
# <img src="data:image/png;base64,..." width="1200">
# working on filling Tmp_min
# Model: "sequential_101"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_428 (Dense)            (None, 12)                24
# _________________________________________________________________
# dense_429 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_430 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_431 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.5299471543775096; acc of 0.0%
# <img src="data:image/png;base64,..." width="1200">
# working on filling Tmp_max
# Model: "sequential_102"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_432 (Dense)            (None, 12)                24
# _________________________________________________________________
# dense_433 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_434 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_435 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.6801416992958057; acc of 0.0%
# <img src="data:image/png;base64,..." width="1200">
# working on filling Rain
# Model: "sequential_103"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_436 (Dense)            (None, 12)                24
# _________________________________________________________________
# dense_437 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_438 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_439 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.7059611765242196; acc of 0.0%
# <img src="data:image/png;base64,..." width="1200">
# working on filling Wind Speed
# Model: "sequential_104"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_440 (Dense)            (None, 12)                24
# _________________________________________________________________
# dense_441 (Dense)            (None, 80)                1040
# _________________________________________________________________
# dense_442 (Dense)            (None, 80)                6480
# _________________________________________________________________
# dense_443 (Dense)            (None, 1)                 81
# =================================================================
# Total params: 7,625
# Trainable params: 7,625
# Non-trainable params: 0
# _________________________________________________________________
# Score: loss of 0.6056530447538486; acc of 0.0%
# <img src="data:image/png;base64,..." width="1200">

# %%
Probably useless, looking at CNNs   https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf
