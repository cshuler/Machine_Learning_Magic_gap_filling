# %%
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style> """))


#%matplotlib inline
# %matplotlib notebook
import matplotlib 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy.polynomial.polynomial import polyfit
import seaborn as sns
import os
import datetime
import keras 
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
import requests
import scipy
import tensorflow as tf

pd.set_option('display.max_rows', 200)    
np.set_printoptions(suppress=True)
# Out:
# <style>
#     div#notebook-container { width: 95%;} div#menubar-container { width: 85%; } div#maintoolbar-container { width: 99%; } </style>

# %% [markdown]
# ## Define functions used here

# %%
def baseflow_separator(date_vector, flow_vector, plotme=False, Station_name=None):

    N = 5                     # averaging window, number of days
    tp_test_factor = 0.9      # turning point test factor     (If 90 percent of a given minimum (the “turning point test factor”) is less than both adjacent minimums, then that minimum is a turning point.)
                                                                              # eill be final processed dictionary of dataframes
    Site=[]; SumTotal=[]; SumBF=[]; SumRO=[]; AveTotal=[]; AveBF=[]; AveRO=[]; BFTF=[]; ROTF=[]  # lists for sumary dataframe

    mean_dates = []; mins = []; means = []
    for i in range(1,len(date_vector)-N,N):                         # mikes code, still not sure I understand it all
        N_day_data = []
        for j in range(0,N-1):
            N_day_data.append(float(flow_vector[i+j]))
        mean_dates.append(date_vector[i+(N//2)])
        mean_point = [date_vector[i+(N//2)]]
        N_day_mean = np.mean(N_day_data)
        mean_point.append(N_day_mean)
        means.append(mean_point)
        min_point = [date_vector[i+(N//2)]]
        N_day_min = np.min(N_day_data)
        min_point.append(N_day_min)
        mins.append(min_point)

    turning_points = []; tp_dates = []; tp_flow = []; sf_dates = []; sf_flow = [];     # mikes code, still not sure I understand it all
    for i in range(0,len(mins)-1,1):
        if (tp_test_factor*(mins[i][1]))<mins[i+1][1] and (tp_test_factor*(mins[i][1]))<mins[i-1][1]:
            turning_points.append(mins[i])
            tp_dates.append(mins[i][0])
            tp_flow.append(mins[i][1])

    keyname = 'Total_flow_{}'.format(Station_name)         
            
    Total_flows = pd.DataFrame({'Date': date_vector, keyname: flow_vector })
    Baseflows = pd.DataFrame({'Date': tp_dates, 'Base_flow_CFS': tp_flow })  
    All_flows = Total_flows.merge(Baseflows, how='outer', on='Date')                     # final dataframe with separated values of flow
    All_flows['Base_flow_CFS'].interpolate(inplace=True)                                 # baseflows were only calculated at turning points. here linearly interpolate to give a value for each day
    All_flows['Runoff_CFS'] = All_flows[keyname] - All_flows['Base_flow_CFS']
    All_flows['Runoff_CFS'] = All_flows['Runoff_CFS'].clip(lower=0)    # convert any negative runoff values to zero

    RO_mean = All_flows['Runoff_CFS'].mean()
    BF_mean = All_flows['Base_flow_CFS'].mean()
    TF_mean = All_flows[keyname].mean()   
    
    # plot stuff
    if plotme == True:
        fig, ax = plt.subplots(figsize=(8, 3))
        ax.plot(All_flows['Date'],All_flows[keyname], '-',label='Total daily flow', marker='.')
        ax.plot(All_flows['Date'],All_flows['Base_flow_CFS'], '-',label='Baseflow', marker='.')
        ax.set_title("Baseflow separated Streamflow at {}".format(Station_name))
        ax.legend()
        plt.ylabel('Discharge (CFS)')

        plt.xticks(rotation=20)
        plt.tight_layout()
        
    print("Ave.RO = {:.2f}, Ave.BF = {:.2f}, Ave.TF = {:.2f}".format(RO_mean, BF_mean, TF_mean))

    return All_flows, RO_mean, BF_mean, TF_mean

# %% [markdown]
# ## Grab data

# %%
url = "https://raw.githubusercontent.com/cshuler/ASPA-UH_Integrated_Modeling_Framework/master/ASPA-UH_Stream_REPO/workspace/All_consolodated_Q_m3ps.csv"
save_to = os.path.join(".", 'Data', "All_consolodated_Q_m3ps.csv")

r = requests.get(url, allow_redirects=True)
open(save_to, 'wb').write(r.content)
# Out:
# 16200025

# %% [markdown]
# ## process Data

# %%
rawdata = pd.read_csv(save_to ,index_col=0,parse_dates=True)

dat = rawdata.resample('D').mean()     # subsample the 15 min data into daily values
dat = dat[10:]                          # this just to cut out some of the beginning days with no streamflows

data = pd.DataFrame(index=dat.index)
for column in dat:
    new_name = column.split("_")[0]+"_CFS"
    data[new_name] = dat[column]*35.314666212661 

data.plot(subplots=True, figsize=(12, 10))
plt.tight_layout()
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="799.259315720969">

# %% [markdown]
# ## Check on correlation between stations

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

corr = data.corr()
sns.heatmap(corr,  xticklabels=data.columns.values, yticklabels=data.columns.values, ax=ax1)
ax1.set_title("Correlation with Maloata")


## remove Maloata from data  new plot due to low correlations
data = data.loc[:, data.columns != 'Malota_CFS']

corr = data.corr()
sns.heatmap(corr,  xticklabels=data.columns.values, yticklabels=data.columns.values, ax=ax2)
plt.tight_layout()
ax2.set_title("Correlation NO Maloata")

# note that unless the data variable is regenerated up above both of these plots will be the same.
# Out:
# <img src="data:image/png;base64,..." width="665.9259729686294">
# Text(0.5, 1, 'Correlation NO Maloata')

# %% [markdown]
# ### determine what proportion of data is misssing. This will be used to praramaterize the validation exercise

# %%
data_date_range = data.index.max()-data.index.min()      #The total number of days in total data record, including gaps
pct_existing_list=[]

for i in data:                               # for each station name e.g "Fagaalu_CFS"
    tempframe = data[i]
    tempframe = tempframe.dropna()                                   
    temp_day_count = tempframe.index.max()-tempframe.index.min()     # find the number of days of actual data
    pct_existing = temp_day_count/data_date_range                    
    pct_existing_list.append(pct_existing)
    
Ave_amount_existing_data = np.mean(pct_existing_list)
print("the amount of data in each station ranges from {:.2f}%  to {:.2f}%, average is {:.2f}%".format(min(pct_existing_list), max(pct_existing_list), Ave_amount_existing_data))

# for now use 50%
Ave_amount_existing_data = .8
# Out:
# the amount of data in each station ranges from 0.66%  to 0.96%, average is 0.80%

# %% [markdown]
# # Run a single instance of gap filling validation based on selection of one station

# %%
# just select perfect no gap dataset 
data_perfect = data.dropna()

data_perfect.plot(subplots=False, figsize=(12, 4))
plt.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="1199.2593439779878">

# %% [markdown]
# ## Set up the training sections

# %%
# create the artifically gapped dataset
Test_Station = "Afono_CFS"   #   Options are 'Fagaalu_CFS', 'Leone_CFS', 'Fagasa_CFS', 'Afono_CFS', 'Nuuuli_CFS','Vaipito_CFS', 'Fagaitua_CFS'  (=i in the loop below) 

trainlist = list(data_perfect.columns.copy())                 # the list of all the other stations with which to use to train the network
trainlist.remove(Test_Station)                        # remove the one station that is being gappped, all others are used for training

print("gap filling for station {}".format(Test_Station));  print("Training with stations {}".format(trainlist))

# select different portions of the dataset based on a % of data to "gap" off of the end of the validataion station
n = len(data_perfect[i])  # total number of days in the perfect dataset
how_much_to_delete = 1-Ave_amount_existing_data                      # Has to be   0 < x < 1  cant be 0 or 1. (delete the inverse of the %exsiting list)
stop_idx = n-int((how_much_to_delete)*n)
Train_End = data_perfect.index[stop_idx]                # end of the training data period, i.e. training data omits data after this data 
Train_Start = data_perfect.index[0]                      # start of the training data period (always the beginning of data all 

X_train = data_perfect.loc[Train_Start:Train_End,trainlist].values             
y_train = data_perfect.loc[Train_Start:Train_End,Test_Station].values  

#scale values appropriately
scaler = StandardScaler().fit(X_train)   # Define the scaler 
X_train = scaler.transform(X_train)      # Scale the train set

# plot
fig, ax = plt.subplots( figsize=(12, 3) )
plt.plot(data_perfect.loc[Train_Start:Train_End].index, X_train, color='grey', alpha = .2)    # show the scaled y training data (note it is scaled so it is small)
plt.plot(data_perfect.loc[Train_Start:Train_End].index, y_train, color='red', alpha = .9)     # show the unscaled y training data  (with the gap)
plt.plot(data_perfect.index, data_perfect[Test_Station], color='k', alpha = .3)               # show the actual y data without the gap
plt.title("traning x data in grey, training y data in red")
# Out:
# gap filling for station Afono_CFS
# Training with stations ['Fagaalu_CFS', 'Leone_CFS', 'Fagasa_CFS', 'Nuuuli_CFS', 'Vaipito_CFS', 'Fagaitua_CFS']
# <img src="data:image/png;base64,..." width="1199.2593439779878">
# Text(0.5, 1.0, 'traning x data in grey, training y data in red')

# %%
# initialize the deep learning model 
model = Sequential()

model.add(Dense(20, activation='relu', input_shape=(len(trainlist),)))
model.add(Dense(100, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dense(1, activation='relu'))
#model.summary()

# train the network using data from the one station
model.compile(optimizer='Nadam', loss='mse', metrics=['mse'])
#model.compile(loss='mean_squared_error',  optimizer='Nadam',  metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=2000, verbose=1)

plt.figure(figsize=(10,4))
plt.plot(history.history['loss'], label="poo")   # can use plt.semilogy(    too
plt.ylabel("Training loss")
plt.xlabel("Epochs")
plt.title("final model MSE = {:.2f}".format(history.history['loss'][-1]))
plt.grid();
# Out:
# Epoch 1/2000
# 423/423 [==============================] - 1s 2ms/step - loss: 43.3147 - mean_squared_error: 43.3147
# Epoch 2/2000
# 423/423 [==============================] - 0s 54us/step - loss: 8.3349 - mean_squared_error: 8.3349
# Epoch 3/2000
# 423/423 [==============================] - 0s 59us/step - loss: 6.7435 - mean_squared_error: 6.7435
# Epoch 4/2000
# 423/423 [==============================] - 0s 59us/step - loss: 5.3203 - mean_squared_error: 5.3203
# Epoch 5/2000
# 423/423 [==============================] - 0s 59us/step - loss: 5.3698 - mean_squared_error: 5.3698
# Epoch 6/2000
# 423/423 [==============================] - 0s 57us/step - loss: 5.0449 - mean_squared_error: 5.0449
# Epoch 7/2000
# 423/423 [==============================] - 0s 52us/step - loss: 6.6160 - mean_squared_error: 6.6160
# Epoch 8/2000
# 423/423 [==============================] - 0s 54us/step - loss: 4.3112 - mean_squared_error: 4.3112
# Epoch 9/2000
# 423/423 [==============================] - 0s 52us/step - loss: 4.3108 - mean_squared_error: 4.3108
# Epoch 10/2000
# 423/423 [==============================] - 0s 52us/step - loss: 4.0231 - mean_squared_error: 4.0231
# Epoch 11/2000
# 423/423 [==============================] - 0s 52us/step - loss: 4.3454 - mean_squared_error: 4.3454
# Epoch 12/2000
# 423/423 [==============================] - 0s 52us/step - loss: 4.1470 - mean_squared_error: 4.1470
# Epoch 13/2000
# 423/423 [==============================] - 0s 52us/step - loss: 3.5963 - mean_squared_error: 3.5963
# Epoch 14/2000
# 423/423 [==============================] - 0s 50us/step - loss: 3.6919 - mean_squared_error: 3.6919
# Epoch 15/2000
# 423/423 [==============================] - 0s 49us/step - loss: 3.3818 - mean_squared_error: 3.3818
# Epoch 16/2000
# 423/423 [==============================] - 0s 49us/step - loss: 3.6011 - mean_squared_error: 3.6011
# Epoch 17/2000
# 423/423 [==============================] - 0s 52us/step - loss: 3.4637 - mean_squared_error: 3.4637
# Epoch 18/2000
# 423/423 [==============================] - 0s 47us/step - loss: 3.2527 - mean_squared_error: 3.2527
# Epoch 19/2000
# 423/423 [==============================] - 0s 52us/step - loss: 3.6521 - mean_squared_error: 3.6521
# Epoch 20/2000
# 423/423 [==============================] - 0s 47us/step - loss: 3.1469 - mean_squared_error: 3.1469
# Epoch 21/2000
# 423/423 [==============================] - 0s 49us/step - loss: 2.9047 - mean_squared_error: 2.9047
# Epoch 22/2000
# 423/423 [==============================] - 0s 50us/step - loss: 3.1593 - mean_squared_error: 3.1593
# Epoch 23/2000
# 423/423 [==============================] - 0s 61us/step - loss: 2.8193 - mean_squared_error: 2.8193
# Epoch 24/2000
# 423/423 [==============================] - 0s 85us/step - loss: 2.8604 - mean_squared_error: 2.8604
# Epoch 25/2000
# 423/423 [==============================] - 0s 71us/step - loss: 2.8867 - mean_squared_error: 2.8867
# Epoch 26/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.4785 - mean_squared_error: 2.4785
# Epoch 27/2000
# 423/423 [==============================] - 0s 54us/step - loss: 2.4326 - mean_squared_error: 2.4326
# Epoch 28/2000
# 423/423 [==============================] - 0s 66us/step - loss: 2.7797 - mean_squared_error: 2.7797
# Epoch 29/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.2378 - mean_squared_error: 2.2378
# Epoch 30/2000
# 423/423 [==============================] - 0s 66us/step - loss: 2.6277 - mean_squared_error: 2.6277
# Epoch 31/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.5858 - mean_squared_error: 2.5858
# Epoch 32/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.7559 - mean_squared_error: 2.7559
# Epoch 33/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.4395 - mean_squared_error: 2.4395
# Epoch 34/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.9926 - mean_squared_error: 1.9926
# Epoch 35/2000
# 423/423 [==============================] - 0s 64us/step - loss: 2.4608 - mean_squared_error: 2.4608
# Epoch 36/2000
# 423/423 [==============================] - 0s 57us/step - loss: 1.9393 - mean_squared_error: 1.9393
# Epoch 37/2000
# 423/423 [==============================] - 0s 57us/step - loss: 2.0308 - mean_squared_error: 2.0308
# Epoch 38/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.6300 - mean_squared_error: 1.6300
# Epoch 39/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.8552 - mean_squared_error: 1.8552
# Epoch 40/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.6289 - mean_squared_error: 1.6289
# Epoch 41/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.5871 - mean_squared_error: 1.5871
# Epoch 42/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.6593 - mean_squared_error: 1.6593
# Epoch 43/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.9396 - mean_squared_error: 1.9396
# Epoch 44/2000
# 423/423 [==============================] - 0s 57us/step - loss: 1.4204 - mean_squared_error: 1.4204
# Epoch 45/2000
# 423/423 [==============================] - 0s 59us/step - loss: 1.4938 - mean_squared_error: 1.4938
# Epoch 46/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.4244 - mean_squared_error: 1.4244
# Epoch 47/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.4350 - mean_squared_error: 1.4350
# Epoch 48/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.4293 - mean_squared_error: 1.4293
# Epoch 49/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.7418 - mean_squared_error: 1.7418
# Epoch 50/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.4003 - mean_squared_error: 1.4003
# Epoch 51/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.1981 - mean_squared_error: 1.1981
# Epoch 52/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.4055 - mean_squared_error: 1.4055
# Epoch 53/2000
# 423/423 [==============================] - 0s 59us/step - loss: 1.3872 - mean_squared_error: 1.3872
# Epoch 54/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.2017 - mean_squared_error: 1.2017
# Epoch 55/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.5827 - mean_squared_error: 1.5827
# Epoch 56/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.4434 - mean_squared_error: 1.4434
# Epoch 57/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.5149 - mean_squared_error: 1.5149
# Epoch 58/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.2228 - mean_squared_error: 1.2228
# Epoch 59/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.2231 - mean_squared_error: 1.2231
# Epoch 60/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.0536 - mean_squared_error: 1.0536
# Epoch 61/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.0381 - mean_squared_error: 1.0381
# Epoch 62/2000
# 423/423 [==============================] - 0s 57us/step - loss: 1.0060 - mean_squared_error: 1.0060
# Epoch 63/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.3471 - mean_squared_error: 1.3471
# Epoch 64/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.5800 - mean_squared_error: 1.5800
# Epoch 65/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.2171 - mean_squared_error: 1.2171
# Epoch 66/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.1233 - mean_squared_error: 1.1233
# Epoch 67/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.9264 - mean_squared_error: 0.9264
# Epoch 68/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.2900 - mean_squared_error: 1.2900
# Epoch 69/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.2378 - mean_squared_error: 1.2378
# Epoch 70/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.9868 - mean_squared_error: 0.9868
# Epoch 71/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.9692 - mean_squared_error: 0.9692
# Epoch 72/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.9937 - mean_squared_error: 0.9937
# Epoch 73/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.7908 - mean_squared_error: 0.7908
# Epoch 74/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.9237 - mean_squared_error: 0.9237
# Epoch 75/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8462 - mean_squared_error: 0.8462
# Epoch 76/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.9028 - mean_squared_error: 0.9028
# Epoch 77/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.7936 - mean_squared_error: 0.7936
# Epoch 78/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.7164 - mean_squared_error: 0.7164
# Epoch 79/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.0539 - mean_squared_error: 1.0539
# Epoch 80/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.8612 - mean_squared_error: 0.8612
# Epoch 81/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.9221 - mean_squared_error: 0.9221
# Epoch 82/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.8093 - mean_squared_error: 0.8093
# Epoch 83/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8328 - mean_squared_error: 0.8328
# Epoch 84/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.1158 - mean_squared_error: 1.1158
# Epoch 85/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.7860 - mean_squared_error: 0.7860
# Epoch 86/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8852 - mean_squared_error: 0.8852
# Epoch 87/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.8242 - mean_squared_error: 0.8242
# Epoch 88/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.7455 - mean_squared_error: 0.7455
# Epoch 89/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.9941 - mean_squared_error: 0.9941
# Epoch 90/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.6898 - mean_squared_error: 0.6898
# Epoch 91/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8410 - mean_squared_error: 0.8410
# Epoch 92/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.8612 - mean_squared_error: 0.8612
# Epoch 93/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.6247 - mean_squared_error: 1.6247
# Epoch 94/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.9072 - mean_squared_error: 0.9072
# Epoch 95/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.7620 - mean_squared_error: 1.7620
# Epoch 96/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.1077 - mean_squared_error: 1.1077
# Epoch 97/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.6155 - mean_squared_error: 1.6155
# Epoch 98/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.9973 - mean_squared_error: 0.9973
# Epoch 99/2000
# 423/423 [==============================] - 0s 61us/step - loss: 1.0458 - mean_squared_error: 1.0458
# Epoch 100/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8007 - mean_squared_error: 0.8007
# Epoch 101/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.1610 - mean_squared_error: 1.1610
# Epoch 102/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.8297 - mean_squared_error: 0.8297
# Epoch 103/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.9765 - mean_squared_error: 0.9765
# Epoch 104/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.0894 - mean_squared_error: 1.0894
# Epoch 105/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.9322 - mean_squared_error: 0.9322
# Epoch 106/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.8383 - mean_squared_error: 0.8383
# Epoch 107/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.6483 - mean_squared_error: 0.6483
# Epoch 108/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5540 - mean_squared_error: 0.5540
# Epoch 109/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6093 - mean_squared_error: 0.6093
# Epoch 110/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5730 - mean_squared_error: 0.5730
# Epoch 111/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6304 - mean_squared_error: 0.6304
# Epoch 112/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.5731 - mean_squared_error: 0.5731
# Epoch 113/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6140 - mean_squared_error: 0.6140
# Epoch 114/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5630 - mean_squared_error: 0.5630
# Epoch 115/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.7156 - mean_squared_error: 0.7156
# Epoch 116/2000
# 423/423 [==============================] - 0s 59us/step - loss: 1.1565 - mean_squared_error: 1.1565
# Epoch 117/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.8370 - mean_squared_error: 0.8370
# Epoch 118/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6003 - mean_squared_error: 0.6003
# Epoch 119/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.5465 - mean_squared_error: 0.5465
# Epoch 120/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.6182 - mean_squared_error: 0.6182
# Epoch 121/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5265 - mean_squared_error: 0.5265
# Epoch 122/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.7224 - mean_squared_error: 0.7224
# Epoch 123/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.6274 - mean_squared_error: 0.6274
# Epoch 124/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.4956 - mean_squared_error: 0.4956
# Epoch 125/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.6566 - mean_squared_error: 0.6566
# Epoch 126/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4768 - mean_squared_error: 0.4768
# Epoch 127/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5304 - mean_squared_error: 0.5304
# Epoch 128/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.7345 - mean_squared_error: 0.7345
# Epoch 129/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.6333 - mean_squared_error: 0.6333
# Epoch 130/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6136 - mean_squared_error: 0.6136
# Epoch 131/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5195 - mean_squared_error: 0.5195
# Epoch 132/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.4468 - mean_squared_error: 0.4468
# Epoch 133/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.7305 - mean_squared_error: 0.7305
# Epoch 134/2000
# 423/423 [==============================] - 0s 68us/step - loss: 1.0590 - mean_squared_error: 1.0590
# Epoch 135/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5388 - mean_squared_error: 0.5388
# Epoch 136/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.9906 - mean_squared_error: 0.9906
# Epoch 137/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.6362 - mean_squared_error: 0.6362
# Epoch 138/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.6589 - mean_squared_error: 0.6589
# Epoch 139/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5185 - mean_squared_error: 0.5185
# Epoch 140/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.3444 - mean_squared_error: 1.3444
# Epoch 141/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.8419 - mean_squared_error: 0.8419
# Epoch 142/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.6239 - mean_squared_error: 1.6239
# Epoch 143/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.0344 - mean_squared_error: 1.0344
# Epoch 144/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.6681 - mean_squared_error: 0.6681
# Epoch 145/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5922 - mean_squared_error: 0.5922
# Epoch 146/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.5661 - mean_squared_error: 0.5661
# Epoch 147/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.7067 - mean_squared_error: 0.7067
# Epoch 148/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.5226 - mean_squared_error: 0.5226
# Epoch 149/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3990 - mean_squared_error: 0.3990
# Epoch 150/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3968 - mean_squared_error: 0.3968
# Epoch 151/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.4171 - mean_squared_error: 0.4171
# Epoch 152/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4002 - mean_squared_error: 0.4002
# Epoch 153/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3980 - mean_squared_error: 0.3980
# Epoch 154/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.3955 - mean_squared_error: 0.3955
# Epoch 155/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.4536 - mean_squared_error: 0.4536
# Epoch 156/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3634 - mean_squared_error: 0.3634
# Epoch 157/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.3707 - mean_squared_error: 0.3707
# Epoch 158/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.3899 - mean_squared_error: 0.3899
# Epoch 159/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.3797 - mean_squared_error: 0.3797
# Epoch 160/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6878 - mean_squared_error: 0.6878
# Epoch 161/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.4076 - mean_squared_error: 0.4076
# Epoch 162/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3330 - mean_squared_error: 0.3330
# Epoch 163/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.3516 - mean_squared_error: 0.3516
# Epoch 164/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3368 - mean_squared_error: 0.3368
# Epoch 165/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3774 - mean_squared_error: 0.3774
# Epoch 166/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.3747 - mean_squared_error: 0.3747
# Epoch 167/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3411 - mean_squared_error: 0.3411
# Epoch 168/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.3416 - mean_squared_error: 0.3416
# Epoch 169/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3389 - mean_squared_error: 0.3389
# Epoch 170/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2964 - mean_squared_error: 0.2964
# Epoch 171/2000
# 423/423 [==============================] - 0s 73us/step - loss: 0.3735 - mean_squared_error: 0.3735
# Epoch 172/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5121 - mean_squared_error: 0.5121
# Epoch 173/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6413 - mean_squared_error: 0.6413
# Epoch 174/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.4671 - mean_squared_error: 0.4671
# Epoch 175/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.6366 - mean_squared_error: 0.6366
# Epoch 176/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3827 - mean_squared_error: 0.3827
# Epoch 177/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.4393 - mean_squared_error: 0.4393
# Epoch 178/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.3988 - mean_squared_error: 0.3988
# Epoch 179/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3018 - mean_squared_error: 0.3018
# Epoch 180/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.6315 - mean_squared_error: 0.6315
# Epoch 181/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.4799 - mean_squared_error: 0.4799
# Epoch 182/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.3917 - mean_squared_error: 0.3917
# Epoch 183/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3606 - mean_squared_error: 0.3606
# Epoch 184/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.3333 - mean_squared_error: 0.3333
# Epoch 185/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.4338 - mean_squared_error: 0.4338
# Epoch 186/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4111 - mean_squared_error: 0.4111
# Epoch 187/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3476 - mean_squared_error: 0.3476
# Epoch 188/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.2912 - mean_squared_error: 0.2912
# Epoch 189/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.3783 - mean_squared_error: 0.3783
# Epoch 190/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.3854 - mean_squared_error: 0.3854
# Epoch 191/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.7545 - mean_squared_error: 0.7545
# Epoch 192/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.6364 - mean_squared_error: 0.6364
# Epoch 193/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4102 - mean_squared_error: 0.4102
# Epoch 194/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3504 - mean_squared_error: 0.3504
# Epoch 195/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.4585 - mean_squared_error: 0.4585
# Epoch 196/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.4206 - mean_squared_error: 0.4206
# Epoch 197/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2785 - mean_squared_error: 0.2785
# Epoch 198/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.4289 - mean_squared_error: 0.4289
# Epoch 199/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2980 - mean_squared_error: 0.2980
# Epoch 200/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4980 - mean_squared_error: 0.4980
# Epoch 201/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.3795 - mean_squared_error: 1.3795
# Epoch 202/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.3934 - mean_squared_error: 1.3934
# Epoch 203/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.7290 - mean_squared_error: 0.7290
# Epoch 204/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.8669 - mean_squared_error: 0.8669
# Epoch 205/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.3375 - mean_squared_error: 0.3375
# Epoch 206/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.6733 - mean_squared_error: 0.6733
# Epoch 207/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.7739 - mean_squared_error: 0.7739
# Epoch 208/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4823 - mean_squared_error: 0.4823
# Epoch 209/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3202 - mean_squared_error: 0.3202
# Epoch 210/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.4437 - mean_squared_error: 0.4437
# Epoch 211/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2806 - mean_squared_error: 0.2806
# Epoch 212/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.3456 - mean_squared_error: 0.3456
# Epoch 213/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.2576 - mean_squared_error: 0.2576
# Epoch 214/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2397 - mean_squared_error: 0.2397
# Epoch 215/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4169 - mean_squared_error: 0.4169
# Epoch 216/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.5139 - mean_squared_error: 0.5139
# Epoch 217/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.6196 - mean_squared_error: 0.6196
# Epoch 218/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.4716 - mean_squared_error: 0.4716
# Epoch 219/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2525 - mean_squared_error: 0.2525
# Epoch 220/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.2289 - mean_squared_error: 0.2289
# Epoch 221/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2191 - mean_squared_error: 0.2191
# Epoch 222/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.1973 - mean_squared_error: 0.1973
# Epoch 223/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2133 - mean_squared_error: 0.2133
# Epoch 224/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2224 - mean_squared_error: 0.2224
# Epoch 225/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2429 - mean_squared_error: 0.2429
# Epoch 226/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2322 - mean_squared_error: 0.2322
# Epoch 227/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2945 - mean_squared_error: 0.2945
# Epoch 228/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2703 - mean_squared_error: 0.2703
# Epoch 229/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.2714 - mean_squared_error: 0.2714
# Epoch 230/2000
# 423/423 [==============================] - 0s 64us/step - loss: 1.3017 - mean_squared_error: 1.3017
# Epoch 231/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3661 - mean_squared_error: 0.3661
# Epoch 232/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2840 - mean_squared_error: 0.2840
# Epoch 233/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.4392 - mean_squared_error: 0.4392
# Epoch 234/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2864 - mean_squared_error: 0.2864
# Epoch 235/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2519 - mean_squared_error: 0.2519
# Epoch 236/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2356 - mean_squared_error: 0.2356
# Epoch 237/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2297 - mean_squared_error: 0.2297
# Epoch 238/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2566 - mean_squared_error: 0.2566
# Epoch 239/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2040 - mean_squared_error: 0.2040
# Epoch 240/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2579 - mean_squared_error: 0.2579
# Epoch 241/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2029 - mean_squared_error: 0.2029
# Epoch 242/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2277 - mean_squared_error: 0.2277
# Epoch 243/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2431 - mean_squared_error: 0.2431
# Epoch 244/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3321 - mean_squared_error: 0.3321
# Epoch 245/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1997 - mean_squared_error: 0.1997
# Epoch 246/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2270 - mean_squared_error: 0.2270
# Epoch 247/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1957 - mean_squared_error: 0.1957
# Epoch 248/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1778 - mean_squared_error: 0.1778
# Epoch 249/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1834 - mean_squared_error: 0.1834
# Epoch 250/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1980 - mean_squared_error: 0.1980
# Epoch 251/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.1624 - mean_squared_error: 1.1624
# Epoch 252/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.7657 - mean_squared_error: 0.7657
# Epoch 253/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3709 - mean_squared_error: 0.3709
# Epoch 254/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.3634 - mean_squared_error: 0.3634
# Epoch 255/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2103 - mean_squared_error: 0.2103
# Epoch 256/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1944 - mean_squared_error: 0.1944
# Epoch 257/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1737 - mean_squared_error: 0.1737
# Epoch 258/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1560 - mean_squared_error: 0.1560
# Epoch 259/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1489 - mean_squared_error: 0.1489
# Epoch 260/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1356 - mean_squared_error: 0.1356
# Epoch 261/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1666 - mean_squared_error: 0.1666
# Epoch 262/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1870 - mean_squared_error: 0.1870
# Epoch 263/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1613 - mean_squared_error: 0.1613
# Epoch 264/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1358 - mean_squared_error: 0.1358
# Epoch 265/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1586 - mean_squared_error: 0.1586
# Epoch 266/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1526 - mean_squared_error: 0.1526
# Epoch 267/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1607 - mean_squared_error: 0.1607
# Epoch 268/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2893 - mean_squared_error: 0.2893
# Epoch 269/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2218 - mean_squared_error: 0.2218
# Epoch 270/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1944 - mean_squared_error: 0.1944
# Epoch 271/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.2072 - mean_squared_error: 0.2072
# Epoch 272/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2283 - mean_squared_error: 0.2283
# Epoch 273/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1937 - mean_squared_error: 0.1937
# Epoch 274/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2306 - mean_squared_error: 0.2306
# Epoch 275/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2428 - mean_squared_error: 0.2428
# Epoch 276/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3321 - mean_squared_error: 0.3321
# Epoch 277/2000
# 423/423 [==============================] - 0s 61us/step - loss: 2.3617 - mean_squared_error: 2.3617
# Epoch 278/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.7328 - mean_squared_error: 1.7328
# Epoch 279/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.5776 - mean_squared_error: 0.5776
# Epoch 280/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5678 - mean_squared_error: 0.5678
# Epoch 281/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2878 - mean_squared_error: 0.2878
# Epoch 282/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2241 - mean_squared_error: 0.2241
# Epoch 283/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2013 - mean_squared_error: 0.2013
# Epoch 284/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3928 - mean_squared_error: 0.3928
# Epoch 285/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3089 - mean_squared_error: 0.3089
# Epoch 286/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.2813 - mean_squared_error: 0.2813
# Epoch 287/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2224 - mean_squared_error: 0.2224
# Epoch 288/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2229 - mean_squared_error: 0.2229
# Epoch 289/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2680 - mean_squared_error: 0.2680
# Epoch 290/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.5264 - mean_squared_error: 0.5264
# Epoch 291/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.3508 - mean_squared_error: 0.3508
# Epoch 292/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.5093 - mean_squared_error: 0.5093
# Epoch 293/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2377 - mean_squared_error: 0.2377
# Epoch 294/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2128 - mean_squared_error: 0.2128
# Epoch 295/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1374 - mean_squared_error: 0.1374
# Epoch 296/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1451 - mean_squared_error: 0.1451
# Epoch 297/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1236 - mean_squared_error: 0.1236
# Epoch 298/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1271 - mean_squared_error: 0.1271
# Epoch 299/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1337 - mean_squared_error: 0.1337
# Epoch 300/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1720 - mean_squared_error: 0.1720
# Epoch 301/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1354 - mean_squared_error: 0.1354
# Epoch 302/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1123 - mean_squared_error: 0.1123
# Epoch 303/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1082 - mean_squared_error: 0.1082
# Epoch 304/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1375 - mean_squared_error: 0.1375
# Epoch 305/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1364 - mean_squared_error: 0.1364
# Epoch 306/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.1032 - mean_squared_error: 0.1032
# Epoch 307/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1340 - mean_squared_error: 0.1340
# Epoch 308/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1133 - mean_squared_error: 0.1133
# Epoch 309/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1190 - mean_squared_error: 0.1190
# Epoch 310/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1970 - mean_squared_error: 0.1970
# Epoch 311/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1166 - mean_squared_error: 0.1166
# Epoch 312/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1209 - mean_squared_error: 0.1209
# Epoch 313/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1218 - mean_squared_error: 0.1218
# Epoch 314/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1230 - mean_squared_error: 0.1230
# Epoch 315/2000
# 423/423 [==============================] - 0s 73us/step - loss: 0.0998 - mean_squared_error: 0.0998
# Epoch 316/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1072 - mean_squared_error: 0.1072
# Epoch 317/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.0952 - mean_squared_error: 0.0952
# Epoch 318/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1402 - mean_squared_error: 0.1402
# Epoch 319/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1328 - mean_squared_error: 0.1328
# Epoch 320/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1089 - mean_squared_error: 0.1089
# Epoch 321/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1275 - mean_squared_error: 0.1275
# Epoch 322/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.1229 - mean_squared_error: 0.1229
# Epoch 323/2000
# 423/423 [==============================] - 0s 80us/step - loss: 0.1014 - mean_squared_error: 0.1014
# Epoch 324/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1076 - mean_squared_error: 0.1076
# Epoch 325/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1377 - mean_squared_error: 0.1377
# Epoch 326/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1095 - mean_squared_error: 0.1095
# Epoch 327/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1305 - mean_squared_error: 0.1305
# Epoch 328/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1107 - mean_squared_error: 0.1107
# Epoch 329/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1118 - mean_squared_error: 0.1118
# Epoch 330/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1099 - mean_squared_error: 0.1099
# Epoch 331/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.1498 - mean_squared_error: 0.1498
# Epoch 332/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.1313 - mean_squared_error: 0.1313
# Epoch 333/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1001 - mean_squared_error: 0.1001
# Epoch 334/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1234 - mean_squared_error: 0.1234
# Epoch 335/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1243 - mean_squared_error: 0.1243
# Epoch 336/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1056 - mean_squared_error: 0.1056
# Epoch 337/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.3067 - mean_squared_error: 0.3067
# Epoch 338/2000
# 423/423 [==============================] - 0s 73us/step - loss: 0.1726 - mean_squared_error: 0.1726
# Epoch 339/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1259 - mean_squared_error: 0.1259
# Epoch 340/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1268 - mean_squared_error: 0.1268
# Epoch 341/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1474 - mean_squared_error: 0.1474
# Epoch 342/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1077 - mean_squared_error: 0.1077
# Epoch 343/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1281 - mean_squared_error: 0.1281
# Epoch 344/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1857 - mean_squared_error: 0.1857
# Epoch 345/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.2350 - mean_squared_error: 0.2350
# Epoch 346/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.1463 - mean_squared_error: 0.1463
# Epoch 347/2000
# 423/423 [==============================] - 0s 73us/step - loss: 0.1419 - mean_squared_error: 0.1419
# Epoch 348/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1740 - mean_squared_error: 0.1740
# Epoch 349/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2243 - mean_squared_error: 0.2243
# Epoch 350/2000
# 423/423 [==============================] - 0s 66us/step - loss: 1.4555 - mean_squared_error: 1.4555
# Epoch 351/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.8389 - mean_squared_error: 0.8389
# Epoch 352/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.6057 - mean_squared_error: 0.6057
# Epoch 353/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2411 - mean_squared_error: 0.2411
# Epoch 354/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1547 - mean_squared_error: 0.1547
# Epoch 355/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2519 - mean_squared_error: 0.2519
# Epoch 356/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1541 - mean_squared_error: 0.1541
# Epoch 357/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1352 - mean_squared_error: 0.1352
# Epoch 358/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1802 - mean_squared_error: 0.1802
# Epoch 359/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.5593 - mean_squared_error: 0.5593
# Epoch 360/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2603 - mean_squared_error: 0.2603
# Epoch 361/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.2292 - mean_squared_error: 0.2292
# Epoch 362/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.1669 - mean_squared_error: 0.1669
# Epoch 363/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2387 - mean_squared_error: 0.2387
# Epoch 364/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.2163 - mean_squared_error: 0.2163
# Epoch 365/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1683 - mean_squared_error: 0.1683
# Epoch 366/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1669 - mean_squared_error: 0.1669
# Epoch 367/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0976 - mean_squared_error: 0.0976
# Epoch 368/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0951 - mean_squared_error: 0.0951
# Epoch 369/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0849 - mean_squared_error: 0.0849
# Epoch 370/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0763 - mean_squared_error: 0.0763
# Epoch 371/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0891 - mean_squared_error: 0.0891
# Epoch 372/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0727 - mean_squared_error: 0.0727
# Epoch 373/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.0766 - mean_squared_error: 0.0766
# Epoch 374/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0884 - mean_squared_error: 0.0884
# Epoch 375/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0864 - mean_squared_error: 0.0864
# Epoch 376/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.0777 - mean_squared_error: 0.0777
# Epoch 377/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0968 - mean_squared_error: 0.0968
# Epoch 378/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0808 - mean_squared_error: 0.0808
# Epoch 379/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0942 - mean_squared_error: 0.0942
# Epoch 380/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0835 - mean_squared_error: 0.0835
# Epoch 381/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0733 - mean_squared_error: 0.0733
# Epoch 382/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0741 - mean_squared_error: 0.0741
# Epoch 383/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0871 - mean_squared_error: 0.0871
# Epoch 384/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.0777 - mean_squared_error: 0.0777
# Epoch 385/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0726 - mean_squared_error: 0.0726
# Epoch 386/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0744 - mean_squared_error: 0.0744
# Epoch 387/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0705 - mean_squared_error: 0.0705
# Epoch 388/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0891 - mean_squared_error: 0.0891
# Epoch 389/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0828 - mean_squared_error: 0.0828
# Epoch 390/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0742 - mean_squared_error: 0.0742
# Epoch 391/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1150 - mean_squared_error: 0.1150
# Epoch 392/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.1411 - mean_squared_error: 0.1411
# Epoch 393/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.1475 - mean_squared_error: 0.1475
# Epoch 394/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1127 - mean_squared_error: 0.1127
# Epoch 395/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0928 - mean_squared_error: 0.0928
# Epoch 396/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0903 - mean_squared_error: 0.0903
# Epoch 397/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1184 - mean_squared_error: 0.1184
# Epoch 398/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1623 - mean_squared_error: 0.1623
# Epoch 399/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1493 - mean_squared_error: 0.1493
# Epoch 400/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1862 - mean_squared_error: 0.1862
# Epoch 401/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1263 - mean_squared_error: 0.1263
# Epoch 402/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.1585 - mean_squared_error: 0.1585
# Epoch 403/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1875 - mean_squared_error: 0.1875
# Epoch 404/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.1050 - mean_squared_error: 0.1050
# Epoch 405/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0976 - mean_squared_error: 0.0976
# Epoch 406/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1198 - mean_squared_error: 0.1198
# Epoch 407/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.2989 - mean_squared_error: 0.2989
# Epoch 408/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1695 - mean_squared_error: 0.1695
# Epoch 409/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1131 - mean_squared_error: 0.1131
# Epoch 410/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1069 - mean_squared_error: 0.1069
# Epoch 411/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1014 - mean_squared_error: 0.1014
# Epoch 412/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0907 - mean_squared_error: 0.0907
# Epoch 413/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0931 - mean_squared_error: 0.0931
# Epoch 414/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0730 - mean_squared_error: 0.0730
# Epoch 415/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0733 - mean_squared_error: 0.0733
# Epoch 416/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0635 - mean_squared_error: 0.0635
# Epoch 417/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0615 - mean_squared_error: 0.0615
# Epoch 418/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0668 - mean_squared_error: 0.0668
# Epoch 419/2000
# ...
# Epoch 1865/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.1357 - mean_squared_error: 0.1357
# Epoch 1866/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.2811 - mean_squared_error: 0.2811
# Epoch 1867/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1384 - mean_squared_error: 0.1384
# Epoch 1868/2000
# 423/423 [==============================] - ETA: 0s - loss: 0.1279 - mean_squared_error: 0.12 - 0s 57us/step - loss: 0.0719 - mean_squared_error: 0.0719
# Epoch 1869/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0499 - mean_squared_error: 0.0499
# Epoch 1870/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0334 - mean_squared_error: 0.0334
# Epoch 1871/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 1872/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 1873/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 1874/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 1875/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 1876/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 1877/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 1878/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 1879/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 1880/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 1881/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 1882/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 1883/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1884/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 1885/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1886/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 1887/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 1888/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 1889/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 1890/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 1891/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 1892/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 1893/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 1894/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 1895/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 1896/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 1897/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 1898/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 1899/2000
# 423/423 [==============================] - 0s 66us/step - loss: 9.6314e-04 - mean_squared_error: 9.6314e-04
# Epoch 1900/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 1901/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 1902/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 1903/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1904/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1905/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0034 - mean_squared_error: 0.0034
# Epoch 1906/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 1907/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0078 - mean_squared_error: 0.0078
# Epoch 1908/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 1909/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 1910/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 1911/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0082 - mean_squared_error: 0.0082
# Epoch 1912/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0098 - mean_squared_error: 0.0098
# Epoch 1913/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 1914/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 1915/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0209 - mean_squared_error: 0.0209
# Epoch 1916/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 1917/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 1918/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 1919/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 1920/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0100 - mean_squared_error: 0.0100
# Epoch 1921/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 1922/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 1923/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 1924/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0089 - mean_squared_error: 0.0089
# Epoch 1925/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 1926/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 1927/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0355 - mean_squared_error: 0.0355
# Epoch 1928/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0382 - mean_squared_error: 0.0382
# Epoch 1929/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0538 - mean_squared_error: 0.0538
# Epoch 1930/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0357 - mean_squared_error: 0.0357
# Epoch 1931/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0197 - mean_squared_error: 0.0197
# Epoch 1932/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 1933/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 1934/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 1935/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0244 - mean_squared_error: 0.0244
# Epoch 1936/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 1937/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0289 - mean_squared_error: 0.0289
# Epoch 1938/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0573 - mean_squared_error: 0.0573
# Epoch 1939/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.2320 - mean_squared_error: 0.2320
# Epoch 1940/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.1905 - mean_squared_error: 0.1905
# Epoch 1941/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.1101 - mean_squared_error: 0.1101
# Epoch 1942/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0547 - mean_squared_error: 0.0547
# Epoch 1943/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0668 - mean_squared_error: 0.0668
# Epoch 1944/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0371 - mean_squared_error: 0.0371
# Epoch 1945/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0448 - mean_squared_error: 0.0448
# Epoch 1946/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0275 - mean_squared_error: 0.0275
# Epoch 1947/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 1948/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 1949/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 1950/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 1951/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0454 - mean_squared_error: 0.0454
# Epoch 1952/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0396 - mean_squared_error: 0.0396
# Epoch 1953/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0204 - mean_squared_error: 0.0204
# Epoch 1954/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1159 - mean_squared_error: 0.1159
# Epoch 1955/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1369 - mean_squared_error: 0.1369
# Epoch 1956/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.3652 - mean_squared_error: 0.3652
# Epoch 1957/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1691 - mean_squared_error: 0.1691
# Epoch 1958/2000
# 423/423 [==============================] - 0s 99us/step - loss: 0.2029 - mean_squared_error: 0.2029
# Epoch 1959/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.1522 - mean_squared_error: 0.1522
# Epoch 1960/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0807 - mean_squared_error: 0.0807
# Epoch 1961/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0706 - mean_squared_error: 0.0706
# Epoch 1962/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0321 - mean_squared_error: 0.0321
# Epoch 1963/2000
# 423/423 [==============================] - 0s 71us/step - loss: 0.0146 - mean_squared_error: 0.0146
# Epoch 1964/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 1965/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 1966/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 1967/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 1968/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0074 - mean_squared_error: 0.0074
# Epoch 1969/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 1970/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 1971/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 1972/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 1973/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 1974/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 1975/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 1976/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0029 - mean_squared_error: 0.0029
# Epoch 1977/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 1978/2000
# 423/423 [==============================] - 0s 54us/step - loss: 0.0023 - mean_squared_error: 0.0023
# Epoch 1979/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0028 - mean_squared_error: 0.0028
# Epoch 1980/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 1981/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 1982/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 1983/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 1984/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 1985/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 1986/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 1987/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 1988/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 1989/2000
# 423/423 [==============================] - 0s 59us/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 1990/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0018 - mean_squared_error: 0.0018
# Epoch 1991/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 1992/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 1993/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0027 - mean_squared_error: 0.0027
# Epoch 1994/2000
# 423/423 [==============================] - 0s 68us/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 1995/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 1996/2000
# 423/423 [==============================] - 0s 66us/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 1997/2000
# 423/423 [==============================] - 0s 64us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1998/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 1999/2000
# 423/423 [==============================] - 0s 61us/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 2000/2000
# 423/423 [==============================] - 0s 57us/step - loss: 0.0012 - mean_squared_error: 0.0012
# <img src="data:image/png;base64,..." width="999.2593298494784">

# %% [markdown]
# ## set up the prediction

# %%
Predict_Start = data_perfect.index[(stop_idx)]                # Start of the validatiaon data period, = end of training data 
Predict_End = data_perfect.index[-1]                      # end of the validation data period (always the end of data all)

X_predict_known = data_perfect.loc[Predict_Start:Predict_End,trainlist].values 
#scale values appropriately
scaler = StandardScaler().fit(X_predict_known)   # Define the scaler 
X_predict_known = scaler.transform(X_predict_known) # Scale the train set

y_predict_unknown = model.predict(X_predict_known)
y_predict_unknown = y_predict_unknown.reshape([np.shape(y_predict_unknown)[0]]).tolist()

x = np.squeeze(data_perfect.loc[Predict_Start:Predict_End][Test_Station])    # the actual data from the staton that was gapped
y = y_predict_unknown                                                        # the network generated data for the validation period   

# plot
fig, ax = plt.subplots( figsize=(12, 3) )
plt.plot(data_perfect.loc[Predict_Start:Predict_End].index, y_predict_unknown, color='red', alpha = .9)     # show the unscaled y training data  (with the gap)
plt.plot(data_perfect.loc[Predict_Start:Predict_End].index, x, color='green', alpha = .9)     # show the real test station data that was removed in the training
plt.plot(data_perfect.index, data_perfect[Test_Station], color='k', alpha = .3)               # show the actual y data without the gap
plt.title("Predicted data in red, real data in green")
# Out:
# <img src="data:image/png;base64,..." width="1199.2593439779878">
# Text(0.5, 1.0, 'Predicted data in red, real data in green')

# %%
slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)                              # get stats on regression
mea = np.mean(np.abs(x-y))
rmse = np.sqrt(np.mean(np.abs(x-y)**2))                                     # couple more basic stats on the residuals, Mean absolute errir and root RMSE root mean squared error
Std_RMSE = rmse/((np.mean(x)+np.mean(y))/2)                                 # standardize the RMSE as a % of the mean

fig2, ax = plt.subplots(1, 3, figsize=(10, 3))
ax[0].plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)),  color = 'k', linestyle = "--")    # plot the linear regresion line 
ax[0].scatter(x, y, label="r2={0:1.2f}, slope={1:1.2f}\nRMSE={2:1.2f} S_RMSE={3:1.2f}".format(r_value, slope, rmse, Std_RMSE))   
ax[1].plot(history.history['mean_squared_error'])
ax[0].set_title('Actual vs simulated data')
ax[1].set_title('MSE vs. Epoch')

# run a baseflow separation on the actual and predicted datasets to see how they compare
Predict_date_vector = data_perfect.loc[Predict_Start:Predict_End].index 
junk, RO_mean_predict,BF_mean_predict,TF_mean_predict  = baseflow_separator(Predict_date_vector, y_predict_unknown, True)
junk, RO_mean_known, BF_mean_known, TF_mean_known     = baseflow_separator(Predict_date_vector, x, True)
index = np.arange(3);  bar_width = 0.3   # just for plotting and offsetting the bars

RO_pct_ERR = (RO_mean_predict-RO_mean_known)/RO_mean_known
BF_pct_ERR = (BF_mean_predict-BF_mean_known)/BF_mean_known
TF_pct_ERR = (TF_mean_predict-TF_mean_known)/TF_mean_known

# plot comparison of streamflows baseflow separated style
ax[2].bar(index, (RO_mean_predict,BF_mean_predict, TF_mean_predict), width=bar_width, alpha=.3, label='Predicted')
ax[2].bar(index+bar_width, (RO_mean_known,BF_mean_known, TF_mean_known), width=bar_width, alpha=.3, label='real')
ax[2].set_xticklabels([None, "RO", "BF", "TF"])
plt.legend()

print("OVERALL RMSE = {}\nOVERALL Std_RMSE = {}\nOVERALL r2 = {}\nOVERALL Slope = {}"
      .format( np.mean(rmse),   np.mean(Std_RMSE), np.mean(r_value), np.mean(slope)))

print("RO_pct_ERR = {:.2f}, BF_pct_ERR = {:.2f}, TF_pct_ERR = {:.2f}".format( RO_pct_ERR, BF_pct_ERR, TF_pct_ERR))
# Out:
# <img src="data:image/png;base64,..." width="999.2593298494784">
# <img src="data:image/png;base64,..." width="799.259315720969">
# Ave.RO = 2.88, Ave.BF = 0.51, Ave.TF = 3.32
# <img src="data:image/png;base64,..." width="799.259315720969">
# Ave.RO = 0.73, Ave.BF = 0.03, Ave.TF = 0.75
# OVERALL RMSE = 5.16753078480866
# OVERALL Std_RMSE = 2.5381134531345286
# OVERALL r2 = 0.892450940249289
# OVERALL Slope = 2.498260744468005
# RO_pct_ERR = 2.93, BF_pct_ERR = 15.11, TF_pct_ERR = 3.43
